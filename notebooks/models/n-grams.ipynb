# %%
import pandas as pd
import math
from nltk.tokenize import word_tokenize
from collections import Counter, defaultdict

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('../data/dataset.csv', index_col=0)

# %% [markdown]
# ## Tokenize

# %%
train_df = df.sample(2400)
train_list = list(train_df['text'])
train_string = " ".join(train_list).lower()
train_tokens = word_tokenize(train_string)

vocab = set(train_tokens)

test_df = df.sample(600)
test_list = list(test_df['text'])
test_string = " ".join(test_list).lower()
test_tokens = word_tokenize(test_string)

# %% [markdown]
# ## N-grams

# %%
def count_ngrams(tokens, n):
    """Counts n-grams."""
    
    ngrams = [tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1)]
    
    return Counter(ngrams)

def calculate_ngram_probabilities(train_tokens, n, test_tokens, k=0.00001):
    """Calculates n-gram probabilities."""
    
    vocab = set(train_tokens)
    V = len(vocab)
    ngram_counts = count_ngrams(train_tokens, n)
    n_minus_one_gram_counts = count_ngrams(train_tokens, n-1)
    ngram_probabilities = defaultdict(float)
    
    for ngram in ngram_counts:
        prefix = ngram[:-1]
        ngram_counts[ngram] += k
        n_minus_one_gram_counts[prefix] += k
        ngram_probabilities[ngram] = (ngram_counts[ngram] + k) / (n_minus_one_gram_counts[prefix] + k*V)

    for i in range(len(test_tokens)-n+1):
        ngram = tuple(test_tokens[i:i+n])
        if ngram not in ngram_counts:
            ngram_counts[ngram] = k
            prefix = ngram[:-1]
            if prefix not in n_minus_one_gram_counts:
                n_minus_one_gram_counts[prefix] = k
            ngram_probabilities[ngram] = (ngram_counts[ngram] + k) / (n_minus_one_gram_counts[prefix] + k*V)
    
    return ngram_probabilities

# %%
n = 5

ngram_prob = calculate_ngram_probabilities(train_tokens, n, test_tokens)
print(f"Number of {n}-grams:", len(ngram_prob))
# Out:
# Number of 5-grams: 2173586

# %%
ngram_prob
# Out:
# defaultdict(float,
#             {('ewan', 'morrison', 'is', 'a', 'scottish'): 0.5100503409618338,
#              ('morrison', 'is', 'a', 'scottish', 'author'): 0.5100503409618338,
#              ('is', 'a', 'scottish', 'author', 'and'): 0.5100503409618338,
#              ('a',
#               'scottish',
#               'author',
#               'and',
#               'screenwriter'): 0.5100503409618338,
#              ('scottish',
#               'author',
#               'and',
#               'screenwriter',
#               ','): 0.5100503409618338,
#              ('author',
#               'and',
#               'screenwriter',
#               ',',
#               'described'): 0.5100503409618338,
#              ('and',
#               'screenwriter',
#               ',',
#               'described',
#               'as'): 0.5100503409618338,
#              ('screenwriter',
#               ',',
#               'described',
#               'as',
#               '``'): 0.5100503409618338,
#              (',', 'described', 'as', '``', 'the'): 0.6755386522463125,
#              ('described', 'as', '``', 'the', 'most'): 0.1677708564363163,
#              ('as', '``', 'the', 'most', 'fluent'): 0.2524901341453254,
#              ('``', 'the', 'most', 'fluent', 'and'): 0.5100503409618338,
#              ('the',
#               'most',
#               'fluent',
#               'and',
#               'intelligent'): 0.5100503409618338,
#              ('most',
#               'fluent',
#               'and',
#               'intelligent',
#               'writer'): 0.5100503409618338,
#              ('fluent',
#               'and',
#               'intelligent',
#               'writer',
#               'of'): 0.5100503409618338,
#              ('and', 'intelligent', 'writer', 'of', 'his'): 0.5100503409618338,
#              ('intelligent',
#               'writer',
#               'of',
#               'his',
#               'generation'): 0.5100503409618338,
#              ('writer', 'of', 'his', 'generation', 'here'): 0.5100503409618338,
#              ('of', 'his', 'generation', 'here', 'in'): 0.5100503409618338,
#              ('his',
#               'generation',
#               'here',
#               'in',
#               'scotland'): 0.5100503409618338,
#              ('generation',
#               'here',
#               'in',
#               'scotland',
#               "''"): 0.5100503409618338,
#              ('here', 'in', 'scotland', "''", 'by'): 0.5100503409618338,
#              ('in', 'scotland', "''", 'by', 'booker'): 0.5100503409618338,
#              ('scotland', "''", 'by', 'booker', 'judge'): 0.5100503409618338,
#              ("''", 'by', 'booker', 'judge', 'stuart'): 0.5100503409618338,
#              ('by', 'booker', 'judge', 'stuart', 'kelly'): 0.5100503409618338,
#              ('booker', 'judge', 'stuart', 'kelly', '.'): 0.5100503409618338,
#              ('judge', 'stuart', 'kelly', '.', 'early'): 0.5100503409618338,
#              ('stuart', 'kelly', '.', 'early', 'life'): 0.5100503409618338,
#              ('kelly', '.', 'early', 'life', 'morrison'): 0.5100503409618338,
#              ('.', 'early', 'life', 'morrison', 'was'): 0.5100503409618338,
#              ('early', 'life', 'morrison', 'was', 'born'): 0.5100503409618338,
#              ('life', 'morrison', 'was', 'born', 'in'): 0.5100503409618338,
#              ('morrison', 'was', 'born', 'in', 'wick'): 0.5100503409618338,
#              ('was', 'born', 'in', 'wick', ','): 0.5100503409618338,
#              ('born', 'in', 'wick', ',', 'caithness'): 0.5100503409618338,
#              ('in', 'wick', ',', 'caithness', 'in'): 0.5100503409618338,
#              ('wick', ',', 'caithness', 'in', '1968'): 0.5100503409618338,
#              (',', 'caithness', 'in', '1968', ','): 0.5100503409618338,
#              ('caithness', 'in', '1968', ',', 'son'): 0.5100503409618338,
#              ('in', '1968', ',', 'son', 'of'): 0.5100503409618338,
#              ('1968', ',', 'son', 'of', 'the'): 0.5100503409618338,
#              (',', 'son', 'of', 'the', 'singer'): 0.3377727037826409,
#              ('son', 'of', 'the', 'singer', 'edna'): 0.5100503409618338,
#              ('of', 'the', 'singer', 'edna', 'morrison'): 0.5100503409618338,
#              ('the', 'singer', 'edna', 'morrison', 'and'): 0.5100503409618338,
#              ('singer', 'edna', 'morrison', 'and', 'the'): 0.5100503409618338,
#              ('edna', 'morrison', 'and', 'the', 'poet'): 0.5100503409618338,
#              ('morrison', 'and', 'the', 'poet', 'and'): 0.5100503409618338,
#              ('and', 'the', 'poet', 'and', 'librarian'): 0.5100503409618338,
#              ('the', 'poet', 'and', 'librarian', 'david'): 0.5100503409618338,
#              ('poet',
#               'and',
#               'librarian',
#               'david',
#               'morrison'): 0.5100503409618338,
#              ('and',
#               'librarian',
#               'david',
#               'morrison',
#               '.'): 0.5100503409618338,
#              ('librarian', 'david', 'morrison', '.', 'in'): 0.5100503409618338,
#              ('david',
#               'morrison',
#               '.',
#               'in',
#               'interviews'): 0.5100503409618338,
#              ('morrison', '.', 'in', 'interviews', 'and'): 0.5100503409618338,
#              ('.', 'in', 'interviews', 'and', 'essays'): 0.5100503409618338,
#              ('in',
#               'interviews',
#               'and',
#               'essays',
#               'morrison'): 0.5100503409618338,
#              ('interviews',
#               'and',
#               'essays',
#               'morrison',
#               'has'): 0.5100503409618338,
#              ('and',
#               'essays',
#               'morrison',
#               'has',
#               'talked'): 0.5100503409618338,
#              ('essays',
#               'morrison',
#               'has',
#               'talked',
#               'about'): 0.5100503409618338,
#              ('morrison', 'has', 'talked', 'about', 'his'): 0.5100503409618338,
#              ('has',
#               'talked',
#               'about',
#               'his',
#               'unorthodox'): 0.5100503409618338,
#              ('talked',
#               'about',
#               'his',
#               'unorthodox',
#               'childhood'): 0.5100503409618338,
#              ('about',
#               'his',
#               'unorthodox',
#               'childhood',
#               'as'): 0.5100503409618338,
#              ('his',
#               'unorthodox',
#               'childhood',
#               'as',
#               'part'): 0.5100503409618338,
#              ('unorthodox',
#               'childhood',
#               'as',
#               'part',
#               'of'): 0.5100503409618338,
#              ('childhood', 'as', 'part', 'of', 'a'): 0.5100503409618338,
#              ('as', 'part', 'of', 'a', "'hippie"): 0.033377802803212085,
#              ('part', 'of', 'a', "'hippie", 'experiment'): 0.5100503409618338,
#              ('of', 'a', "'hippie", 'experiment', "'"): 0.5100503409618338,
#              ('a', "'hippie", 'experiment', "'", ','): 0.5100503409618338,
#              ("'hippie", 'experiment', "'", ',', 'the'): 0.5100503409618338,
#              ('experiment', "'", ',', 'the', 'childhood'): 0.5100503409618338,
#              ("'", ',', 'the', 'childhood', 'bullying'): 0.5100503409618338,
#              (',', 'the', 'childhood', 'bullying', 'he'): 0.5100503409618338,
#              ('the',
#               'childhood',
#               'bullying',
#               'he',
#               'endured'): 0.5100503409618338,
#              ('childhood',
#               'bullying',
#               'he',
#               'endured',
#               'and'): 0.5100503409618338,
#              ('bullying', 'he', 'endured', 'and', 'the'): 0.5100503409618338,
#              ('he',
#               'endured',
#               'and',
#               'the',
#               'difficulties'): 0.5100503409618338,
#              ('endured',
#               'and',
#               'the',
#               'difficulties',
#               'he'): 0.5100503409618338,
#              ('and',
#               'the',
#               'difficulties',
#               'he',
#               'experienced'): 0.5100503409618338,
#              ('the',
#               'difficulties',
#               'he',
#               'experienced',
#               ','): 0.5100503409618338,
#              ('difficulties',
#               'he',
#               'experienced',
#               ',',
#               'growing'): 0.5100503409618338,
#              ('he', 'experienced', ',', 'growing', 'up'): 0.5100503409618338,
#              ('experienced', ',', 'growing', 'up', 'as'): 0.5100503409618338,
#              (',', 'growing', 'up', 'as', 'a'): 0.5100503409618338,
#              ('growing', 'up', 'as', 'a', 'cultural'): 0.5100503409618338,
#              ('up', 'as', 'a', 'cultural', 'outsider'): 0.5100503409618338,
#              ('as', 'a', 'cultural', 'outsider', 'with'): 0.5100503409618338,
#              ('a', 'cultural', 'outsider', 'with', 'a'): 0.5100503409618338,
#              ('cultural',
#               'outsider',
#               'with',
#               'a',
#               'stutter'): 0.5100503409618338,
#              ('outsider', 'with', 'a', 'stutter', '('): 0.5100503409618338,
#              ('with', 'a', 'stutter', '(', 'stammer'): 0.5100503409618338,
#              ('a', 'stutter', '(', 'stammer', ')'): 0.5100503409618338,
#              ('stutter', '(', 'stammer', ')', '.'): 0.5100503409618338,
#              ('(', 'stammer', ')', '.', 'he'): 0.5100503409618338,
#              ('stammer', ')', '.', 'he', 'claims'): 0.5100503409618338,
#              (')', '.', 'he', 'claims', 'these'): 0.5100503409618338,
#              ('.', 'he', 'claims', 'these', 'experiences'): 0.5100503409618338,
#              ('he',
#               'claims',
#               'these',
#               'experiences',
#               'have'): 0.5100503409618338,
#              ('claims',
#               'these',
#               'experiences',
#               'have',
#               'influenced'): 0.5100503409618338,
#              ('these',
#               'experiences',
#               'have',
#               'influenced',
#               'how'): 0.5100503409618338,
#              ('experiences',
#               'have',
#               'influenced',
#               'how',
#               'he'): 0.5100503409618338,
#              ('have', 'influenced', 'how', 'he', 'found'): 0.5100503409618338,
#              ('influenced', 'how', 'he', 'found', 'his'): 0.5100503409618338,
#              ('how', 'he', 'found', 'his', 'voice'): 0.5100503409618338,
#              ('he', 'found', 'his', 'voice', 'as'): 0.5100503409618338,
#              ('found', 'his', 'voice', 'as', 'writer'): 0.5100503409618338,
#              ('his', 'voice', 'as', 'writer', '.'): 0.5100503409618338,
#              ('voice', 'as', 'writer', '.', 'morrison'): 0.5100503409618338,
#              ('as',
#               'writer',
#               '.',
#               'morrison',
#               'graduated'): 0.5100503409618338,
#              ('writer',
#               '.',
#               'morrison',
#               'graduated',
#               'from'): 0.5100503409618338,
#              ('.',
#               'morrison',
#               'graduated',
#               'from',
#               'glasgow'): 0.5100503409618338,
#              ('morrison',
#               'graduated',
#               'from',
#               'glasgow',
#               'school'): 0.5100503409618338,
#              ('graduated',
#               'from',
#               'glasgow',
#               'school',
#               'of'): 0.5100503409618338,
#              ('from', 'glasgow', 'school', 'of', 'art'): 0.5100503409618338,
#              ('glasgow', 'school', 'of', 'art', 'in'): 0.3377727037826409,
#              ('school', 'of', 'art', 'in', '1990'): 0.5100503409618338,
#              ('of', 'art', 'in', '1990', ','): 0.5100503409618338,
#              ('art', 'in', '1990', ',', 'learned'): 0.5100503409618338,
#              ('in', '1990', ',', 'learned', 'to'): 0.5100503409618338,
#              ('1990', ',', 'learned', 'to', 'manage'): 0.5100503409618338,
#              (',', 'learned', 'to', 'manage', 'his'): 0.5100503409618338,
#              ('learned', 'to', 'manage', 'his', 'stutter'): 0.5100503409618338,
#              ('to', 'manage', 'his', 'stutter', 'and'): 0.5100503409618338,
#              ('manage', 'his', 'stutter', 'and', 'began'): 0.5100503409618338,
#              ('his', 'stutter', 'and', 'began', 'work'): 0.5100503409618338,
#              ('stutter', 'and', 'began', 'work', 'as'): 0.5100503409618338,
#              ('and', 'began', 'work', 'as', 'an'): 0.3377727037826409,
#              ('began', 'work', 'as', 'an', 'art'): 0.3377727037826409,
#              ('work', 'as', 'an', 'art', 'critic'): 0.5100503409618338,
#              ('as', 'an', 'art', 'critic', 'and'): 0.5100503409618338,
#              ('an', 'art', 'critic', 'and', 'filmmaker'): 0.5100503409618338,
#              ('art',
#               'critic',
#               'and',
#               'filmmaker',
#               'before'): 0.5100503409618338,
#              ('critic',
#               'and',
#               'filmmaker',
#               'before',
#               'turning'): 0.5100503409618338,
#              ('and',
#               'filmmaker',
#               'before',
#               'turning',
#               'to'): 0.5100503409618338,
#              ('filmmaker',
#               'before',
#               'turning',
#               'to',
#               'fiction'): 0.5100503409618338,
#              ('before',
#               'turning',
#               'to',
#               'fiction',
#               'writing'): 0.5100503409618338,
#              ('turning', 'to', 'fiction', 'writing', '.'): 0.5100503409618338,
#              ('to', 'fiction', 'writing', '.', 'fiction'): 0.5100503409618338,
#              ('fiction',
#               'writing',
#               '.',
#               'fiction',
#               'morrison'): 0.5100503409618338,
#              ('writing',
#               '.',
#               'fiction',
#               'morrison',
#               'became'): 0.5100503409618338,
#              ('.', 'fiction', 'morrison', 'became', 'a'): 0.5100503409618338,
#              ('fiction',
#               'morrison',
#               'became',
#               'a',
#               'full-time'): 0.5100503409618338,
#              ('morrison',
#               'became',
#               'a',
#               'full-time',
#               'writer'): 0.5100503409618338,
#              ('became', 'a', 'full-time', 'writer', 'in'): 0.5100503409618338,
#              ('a', 'full-time', 'writer', 'in', '2005'): 0.5100503409618338,
#              ('full-time', 'writer', 'in', '2005', 'and'): 0.5100503409618338,
#              ('writer', 'in', '2005', 'and', 'has'): 0.5100503409618338,
#              ('in', '2005', 'and', 'has', 'since'): 0.5100503409618338,
#              ('2005', 'and', 'has', 'since', 'published'): 0.5100503409618338,
#              ('and', 'has', 'since', 'published', 'six'): 0.5100503409618338,
#              ('has',
#               'since',
#               'published',
#               'six',
#               'novels'): 0.5100503409618338,
#              ('since',
#               'published',
#               'six',
#               'novels',
#               'and'): 0.5100503409618338,
#              ('published', 'six', 'novels', 'and', 'one'): 0.5100503409618338,
#              ('six', 'novels', 'and', 'one', 'collection'): 0.5100503409618338,
#              ('novels', 'and', 'one', 'collection', 'of'): 0.5100503409618338,
#              ('and', 'one', 'collection', 'of', 'short'): 0.5100503409618338,
#              ('one',
#               'collection',
#               'of',
#               'short',
#               'stories'): 0.5100503409618338,
#              ('collection', 'of', 'short', 'stories', '.'): 0.1677708564363163,
#              ('of', 'short', 'stories', '.', 'his'): 0.5100503409618338,
#              ('short', 'stories', '.', 'his', 'seventh'): 0.5100503409618338,
#              ('stories', '.', 'his', 'seventh', 'book'): 0.5100503409618338,
#              ('.', 'his', 'seventh', 'book', ','): 0.5100503409618338,
#              ('his', 'seventh', 'book', ',', 'nina'): 0.5100503409618338,
#              ('seventh', 'book', ',', 'nina', 'x'): 0.5100503409618338,
#              ('book', ',', 'nina', 'x', ','): 0.5100503409618338,
#              (',', 'nina', 'x', ',', 'will'): 0.3377727037826409,
#              ('nina', 'x', ',', 'will', 'be'): 0.5100503409618338,
#              ('x', ',', 'will', 'be', 'published'): 0.5100503409618338,
#              (',', 'will', 'be', 'published', 'in'): 0.5100503409618338,
#              ('will', 'be', 'published', 'in', 'april'): 0.3377727037826409,
#              ('be', 'published', 'in', 'april', ','): 0.5100503409618338,
#              ('published', 'in', 'april', ',', '2019.'): 0.5100503409618338,
#              ('in', 'april', ',', '2019.', 'the'): 0.5100503409618338,
#              ('april', ',', '2019.', 'the', 'last'): 0.5100503409618338,
#              (',', '2019.', 'the', 'last', 'book'): 0.5100503409618338,
#              ('2019.', 'the', 'last', 'book', 'you'): 0.5100503409618338,
#              ('the', 'last', 'book', 'you', 'read'): 0.8063532252959804,
#              ('last', 'book', 'you', 'read', 'and'): 0.8063532252959804,
#              ('book', 'you', 'read', 'and', 'other'): 0.8063532252959804,
#              ('you', 'read', 'and', 'other', 'stories'): 0.8063532252959804,
#              ('read',
#               'and',
#               'other',
#               'stories',
#               'morrison'): 0.20159133013347097,
#              ('and', 'other', 'stories', 'morrison', "'s"): 0.5100503409618338,
#              ('other',
#               'stories',
#               'morrison',
#               "'s",
#               'first'): 0.5100503409618338,
#              ('stories',
#               'morrison',
#               "'s",
#               'first',
#               'book'): 0.5100503409618338,
#              ('morrison', "'s", 'first', 'book', ','): 0.5100503409618338,
#              ("'s", 'first', 'book', ',', 'the'): 0.5100503409618338,
#              ('first', 'book', ',', 'the', 'last'): 0.5100503409618338,
#              ('book', ',', 'the', 'last', 'book'): 0.5100503409618338,
#              (',', 'the', 'last', 'book', 'you'): 0.5100503409618338,
#              ('read', 'and', 'other', 'stories', ','): 0.201590923751774,
#              ('and', 'other', 'stories', ',', 'is'): 0.2524901341453254,
#              ('other', 'stories', ',', 'is', 'a'): 0.5100503409618338,
#              ('stories', ',', 'is', 'a', 'short'): 0.5100503409618338,
#              (',', 'is', 'a', 'short', 'story'): 0.3377727037826409,
#              ('is', 'a', 'short', 'story', 'collection'): 0.5100503409618338,
#              ('a',
#               'short',
#               'story',
#               'collection',
#               'which'): 0.5100503409618338,
#              ('short',
#               'story',
#               'collection',
#               'which',
#               'explores'): 0.5100503409618338,
#              ('story',
#               'collection',
#               'which',
#               'explores',
#               'modern'): 0.5100503409618338,
#              ('collection',
#               'which',
#               'explores',
#               'modern',
#               'relationships'): 0.5100503409618338,
#              ('which',
#               'explores',
#               'modern',
#               'relationships',
#               'in'): 0.5100503409618338,
#              ('explores',
#               'modern',
#               'relationships',
#               'in',
#               'the'): 0.5100503409618338,
#              ('modern',
#               'relationships',
#               'in',
#               'the',
#               'era'): 0.5100503409618338,
#              ('relationships', 'in', 'the', 'era', 'of'): 0.5100503409618338,
#              ('in', 'the', 'era', 'of', 'globalisation'): 0.20159133013347097,
#              ('the', 'era', 'of', 'globalisation', 'and'): 0.5100503409618338,
#              ('era', 'of', 'globalisation', 'and', 'was'): 0.5100503409618338,
#              ('of',
#               'globalisation',
#               'and',
#               'was',
#               'described'): 0.5100503409618338,
#              ('globalisation',
#               'and',
#               'was',
#               'described',
#               'by'): 0.5100503409618338,
#              ('and', 'was', 'described', 'by', 'the'): 0.3377727037826409,
#              ('was', 'described', 'by', 'the', 'times'): 0.2524901341453254,
#              ('described', 'by', 'the', 'times', 'as'): 0.5100503409618338,
#              ('by', 'the', 'times', 'as', '``'): 0.5100503409618338,
#              ('the', 'times', 'as', '``', 'the'): 0.5100503409618338,
#              ('times', 'as', '``', 'the', 'most'): 0.5100503409618338,
#              ('as', '``', 'the', 'most', 'compelling'): 0.2524894966470066,
#              ('``',
#               'the',
#               'most',
#               'compelling',
#               'scottish'): 0.5100503409618338,
#              ('the',
#               'most',
#               'compelling',
#               'scottish',
#               'literary'): 0.5100503409618338,
#              ('most',
#               'compelling',
#               'scottish',
#               'literary',
#               'debut'): 0.5100503409618338,
#              ('compelling',
#               'scottish',
#               'literary',
#               'debut',
#               'since'): 0.5100503409618338,
#              ('scottish',
#               'literary',
#               'debut',
#               'since',
#               'trainspotting'): 0.5100503409618338,
#              ('literary',
#               'debut',
#               'since',
#               'trainspotting',
#               '”'): 0.5100503409618338,
#              ('debut', 'since', 'trainspotting', '”', '.'): 0.5100503409618338,
#              ('since',
#               'trainspotting',
#               '”',
#               '.',
#               'bertold'): 0.5100503409618338,
#              ('trainspotting',
#               '”',
#               '.',
#               'bertold',
#               'schoene'): 0.5100503409618338,
#              ('”', '.', 'bertold', 'schoene', 'in'): 0.5100503409618338,
#              ('.', 'bertold', 'schoene', 'in', 'the'): 0.5100503409618338,
#              ('bertold',
#               'schoene',
#               'in',
#               'the',
#               'edinburgh'): 0.5100503409618338,
#              ('schoene',
#               'in',
#               'the',
#               'edinburgh',
#               'companion'): 0.5100503409618338,
#              ('in', 'the', 'edinburgh', 'companion', 'to'): 0.5100503409618338,
#              ('the',
#               'edinburgh',
#               'companion',
#               'to',
#               'contemporary'): 0.5100503409618338,
#              ('edinburgh',
#               'companion',
#               'to',
#               'contemporary',
#               'scottish'): 0.5100503409618338,
#              ('companion',
#               'to',
#               'contemporary',
#               'scottish',
#               'literature'): 0.5100503409618338,
#              ('to',
#               'contemporary',
#               'scottish',
#               'literature',
#               ','): 0.5100503409618338,
#              ('contemporary',
#               'scottish',
#               'literature',
#               ',',
#               'said'): 0.5100503409618338,
#              ('scottish', 'literature', ',', 'said', '``'): 0.5100503409618338,
#              ('literature', ',', 'said', '``', 'morrison'): 0.5100503409618338,
#              (',', 'said', '``', 'morrison', 'is'): 0.5100503409618338,
#              ('said', '``', 'morrison', 'is', 'concerned'): 0.5100503409618338,
#              ('``', 'morrison', 'is', 'concerned', 'with'): 0.5100503409618338,
#              ('morrison',
#               'is',
#               'concerned',
#               'with',
#               'the'): 0.5100503409618338,
#              ('is',
#               'concerned',
#               'with',
#               'the',
#               'indispensable'): 0.20159133013347097,
#              ('concerned',
#               'with',
#               'the',
#               'indispensable',
#               'necessity'): 0.5100503409618338,
#              ('with',
#               'the',
#               'indispensable',
#               'necessity',
#               'of'): 0.5100503409618338,
#              ('the',
#               'indispensable',
#               'necessity',
#               'of',
#               'personal'): 0.5100503409618338,
#              ('indispensable',
#               'necessity',
#               'of',
#               'personal',
#               'relationships'): 0.5100503409618338,
#              ('necessity',
#               'of',
#               'personal',
#               'relationships',
#               ','): 0.5100503409618338,
#              ('of',
#               'personal',
#               'relationships',
#               ',',
#               'the'): 0.5100503409618338,
#              ('personal',
#               'relationships',
#               ',',
#               'the',
#               'heroic'): 0.5100503409618338,
#              ('relationships',
#               ',',
#               'the',
#               'heroic',
#               'effort'): 0.5100503409618338,
#              (',', 'the', 'heroic', 'effort', 'it'): 0.5100503409618338,
#              ('the', 'heroic', 'effort', 'it', 'takes'): 0.5100503409618338,
#              ('heroic', 'effort', 'it', 'takes', 'to'): 0.5100503409618338,
#              ('effort', 'it', 'takes', 'to', 'initiate'): 0.5100503409618338,
#              ('it', 'takes', 'to', 'initiate', ','): 0.5100503409618338,
#              ('takes', 'to', 'initiate', ',', 'trust'): 0.5100503409618338,
#              ('to', 'initiate', ',', 'trust', 'and'): 0.5100503409618338,
#              ('initiate', ',', 'trust', 'and', 'maintain'): 0.5100503409618338,
#              (',', 'trust', 'and', 'maintain', 'them'): 0.5100503409618338,
#              ('trust', 'and', 'maintain', 'them', 'as'): 0.5100503409618338,
#              ('and', 'maintain', 'them', 'as', 'well'): 0.5100503409618338,
#              ('maintain', 'them', 'as', 'well', 'as'): 0.5100503409618338,
#              ('them', 'as', 'well', 'as', 'the'): 0.5100503409618338,
#              ('as', 'well', 'as', 'the', 'common'): 0.008199531274969637,
#              ('well', 'as', 'the', 'common', 'everyday'): 0.5100503409618338,
#              ('as', 'the', 'common', 'everyday', 'trials'): 0.5100503409618338,
#              ('the',
#               'common',
#               'everyday',
#               'trials',
#               'inherent'): 0.5100503409618338,
#              ('common',
#               'everyday',
#               'trials',
#               'inherent',
#               'in'): 0.5100503409618338,
#              ('everyday',
#               'trials',
#               'inherent',
#               'in',
#               'being'): 0.5100503409618338,
#              ('trials',
#               'inherent',
#               'in',
#               'being',
#               'generally'): 0.5100503409618338,
#              ('inherent',
#               'in',
#               'being',
#               'generally',
#               'human'): 0.5100503409618338,
#              ('in', 'being', 'generally', 'human', 'in'): 0.5100503409618338,
#              ('being', 'generally', 'human', 'in', 'our'): 0.5100503409618338,
#              ('generally',
#               'human',
#               'in',
#               'our',
#               'globalised'): 0.5100503409618338,
#              ('human',
#               'in',
#               'our',
#               'globalised',
#               'twenty'): 0.5100503409618338,
#              ('in',
#               'our',
#               'globalised',
#               'twenty',
#               'first-century'): 0.5100503409618338,
#              ('our',
#               'globalised',
#               'twenty',
#               'first-century',
#               'world…undeniably'): 0.5100503409618338,
#              ('globalised',
#               'twenty',
#               'first-century',
#               'world…undeniably',
#               'morrison'): 0.5100503409618338,
#              ('twenty',
#               'first-century',
#               'world…undeniably',
#               'morrison',
#               '’'): 0.5100503409618338,
#              ('first-century',
#               'world…undeniably',
#               'morrison',
#               '’',
#               's'): 0.5100503409618338,
#              ('world…undeniably',
#               'morrison',
#               '’',
#               's',
#               'collection'): 0.5100503409618338,
#              ('morrison', '’', 's', 'collection', 'of'): 0.5100503409618338,
#              ('’', 's', 'collection', 'of', 'short'): 0.5100503409618338,
#              ('s', 'collection', 'of', 'short', 'stories'): 0.5100503409618338,
#              ('collection',
#               'of',
#               'short',
#               'stories',
#               'makes'): 0.16777057497181513,
#              ('of', 'short', 'stories', 'makes', 'a'): 0.5100503409618338,
#              ('short',
#               'stories',
#               'makes',
#               'a',
#               'contribution'): 0.5100503409618338,
#              ('stories',
#               'makes',
#               'a',
#               'contribution',
#               'to'): 0.5100503409618338,
#              ('makes',
#               'a',
#               'contribution',
#               'to',
#               'contemporary'): 0.5100503409618338,
#              ('a',
#               'contribution',
#               'to',
#               'contemporary',
#               'world'): 0.5100503409618338,
#              ('contribution',
#               'to',
#               'contemporary',
#               'world',
#               'literature'): 0.5100503409618338,
#              ('to',
#               'contemporary',
#               'world',
#               'literature',
#               "''"): 0.5100503409618338,
#              ('contemporary',
#               'world',
#               'literature',
#               "''",
#               '.'): 0.5100503409618338,
#              ('world', 'literature', "''", '.', 'the'): 0.5100503409618338,
#              ('literature', "''", '.', 'the', 'last'): 0.5100503409618338,
#              ("''", '.', 'the', 'last', 'book'): 0.5100503409618338,
#              ('.', 'the', 'last', 'book', 'you'): 0.3377727037826409,
#              ('read', 'and', 'other', 'stories', 'led'): 0.20159051737171546,
#              ('and',
#               'other',
#               'stories',
#               'led',
#               'morrison'): 0.5100503409618338,
#              ('other', 'stories', 'led', 'morrison', 'to'): 0.5100503409618338,
#              ('stories', 'led', 'morrison', 'to', 'being'): 0.5100503409618338,
#              ('led',
#               'morrison',
#               'to',
#               'being',
#               'short-listed'): 0.5100503409618338,
#              ('morrison',
#               'to',
#               'being',
#               'short-listed',
#               'for'): 0.5100503409618338,
#              ('to', 'being', 'short-listed', 'for', 'the'): 0.5100503409618338,
#              ('being',
#               'short-listed',
#               'for',
#               'the',
#               'arena'): 0.5100503409618338,
#              ('short-listed',
#               'for',
#               'the',
#               'arena',
#               'magazine'): 0.5100503409618338,
#              ('for', 'the', 'arena', 'magazine', 'man'): 0.5100503409618338,
#              ('the', 'arena', 'magazine', 'man', 'of'): 0.5100503409618338,
#              ('arena', 'magazine', 'man', 'of', 'the'): 0.5100503409618338,
#              ('magazine', 'man', 'of', 'the', 'year'): 0.5100503409618338,
#              ('man', 'of', 'the', 'year', 'award'): 0.30118777627519544,
#              ('of', 'the', 'year', 'award', 'in'): 0.1432614430724115,
#              ('the', 'year', 'award', 'in', '2006.'): 0.3377727037826409,
#              ('year', 'award', 'in', '2006.', 'one'): 0.5100503409618338,
#              ('award', 'in', '2006.', 'one', 'of'): 0.5100503409618338,
#              ('in', '2006.', 'one', 'of', 'the'): 0.5100503409618338,
#              ('2006.', 'one', 'of', 'the', 'short'): 0.5100503409618338,
#              ('one', 'of', 'the', 'short', 'stories'): 0.5100503409618338,
#              ('of', 'the', 'short', 'stories', 'within'): 0.5100503409618338,
#              ('the', 'short', 'stories', 'within', 'it'): 0.5100503409618338,
#              ('short', 'stories', 'within', 'it', 'was'): 0.5100503409618338,
#              ('stories', 'within', 'it', 'was', 'made'): 0.5100503409618338,
#              ('within', 'it', 'was', 'made', 'into'): 0.5100503409618338,
#              ('it', 'was', 'made', 'into', 'the'): 0.2524901341453254,
#              ('was', 'made', 'into', 'the', 'short'): 0.5100503409618338,
#              ('made', 'into', 'the', 'short', 'film'): 0.5100503409618338,
#              ('into', 'the', 'short', 'film', 'none'): 0.5100503409618338,
#              ('the', 'short', 'film', 'none', 'of'): 0.5100503409618338,
#              ('short', 'film', 'none', 'of', 'the'): 0.5100503409618338,
#              ('film', 'none', 'of', 'the', 'above'): 0.5100503409618338,
#              ('none', 'of', 'the', 'above', ','): 0.2524901341453254,
#              ('of', 'the', 'above', ',', 'starring'): 0.5100503409618338,
#              ('the', 'above', ',', 'starring', 'holli'): 0.5100503409618338,
#              ('above',
#               ',',
#               'starring',
#               'holli',
#               'dempsey'): 0.5100503409618338,
#              (',', 'starring', 'holli', 'dempsey', '.'): 0.5100503409618338,
#              ('starring',
#               'holli',
#               'dempsey',
#               '.',
#               'distance'): 0.5100503409618338,
#              ('holli',
#               'dempsey',
#               '.',
#               'distance',
#               'distance'): 0.5100503409618338,
#              ('dempsey',
#               '.',
#               'distance',
#               'distance',
#               'is'): 0.5100503409618338,
#              ('.',
#               'distance',
#               'distance',
#               'is',
#               'morrison'): 0.5100503409618338,
#              ('distance',
#               'distance',
#               'is',
#               'morrison',
#               "'s"): 0.5100503409618338,
#              ('distance',
#               'is',
#               'morrison',
#               "'s",
#               'second'): 0.5100503409618338,
#              ('is', 'morrison', "'s", 'second', 'novel'): 0.5100503409618338,
#              ('morrison', "'s", 'second', 'novel', '–'): 0.5100503409618338,
#              ("'s", 'second', 'novel', '–', '``'): 0.5100503409618338,
#              ('second', 'novel', '–', '``', 'exploring'): 0.5100503409618338,
#              ('novel', '–', '``', 'exploring', 'the'): 0.5100503409618338,
#              ('–', '``', 'exploring', 'the', 'issue'): 0.5100503409618338,
#              ('``', 'exploring', 'the', 'issue', 'of'): 0.5100503409618338,
#              ('exploring',
#               'the',
#               'issue',
#               'of',
#               'long-distance'): 0.5100503409618338,
#              ('the',
#               'issue',
#               'of',
#               'long-distance',
#               'relationships'): 0.5100503409618338,
#              ('issue',
#               'of',
#               'long-distance',
#               'relationships',
#               ','): 0.5100503409618338,
#              ('of',
#               'long-distance',
#               'relationships',
#               ',',
#               'and'): 0.5100503409618338,
#              ('long-distance',
#               'relationships',
#               ',',
#               'and',
#               'through'): 0.5100503409618338,
#              ('relationships',
#               ',',
#               'and',
#               'through',
#               'this'): 0.5100503409618338,
#              (',', 'and', 'through', 'this', ','): 0.5100503409618338,
#              ('and', 'through', 'this', ',', 'jealousy'): 0.5100503409618338,
#              ('through', 'this', ',', 'jealousy', ','): 0.5100503409618338,
#              ('this', ',', 'jealousy', ',', 'phone'): 0.5100503409618338,
#              (',', 'jealousy', ',', 'phone', 'sex'): 0.5100503409618338,
#              ('jealousy', ',', 'phone', 'sex', ','): 0.5100503409618338,
#              (',', 'phone', 'sex', ',', 'parenthood'): 0.5100503409618338,
#              ('phone', 'sex', ',', 'parenthood', ','): 0.5100503409618338,
#              ('sex', ',', 'parenthood', ',', 'paranoia'): 0.5100503409618338,
#              (',', 'parenthood', ',', 'paranoia', ','): 0.5100503409618338,
#              ('parenthood',
#               ',',
#               'paranoia',
#               ',',
#               'alcoholism'): 0.5100503409618338,
#              (',', 'paranoia', ',', 'alcoholism', 'and'): 0.5100503409618338,
#              ('paranoia',
#               ',',
#               'alcoholism',
#               'and',
#               'despair'): 0.5100503409618338,
#              (',', 'alcoholism', 'and', 'despair', "''"): 0.5100503409618338,
#              ('alcoholism', 'and', 'despair', "''", '.'): 0.5100503409618338,
#              ('and', 'despair', "''", '.', 'the'): 0.5100503409618338,
#              ('despair', "''", '.', 'the', 'telegraph'): 0.5100503409618338,
#              ("''", '.', 'the', 'telegraph', 'said'): 0.5100503409618338,
#              ('.', 'the', 'telegraph', 'said', ','): 0.5100503409618338,
#              ('the', 'telegraph', 'said', ',', '``'): 0.5100503409618338,
#              ('telegraph', 'said', ',', '``', '['): 0.5100503409618338,
#              ('said', ',', '``', '[', 'morrison'): 0.2524901341453254,
#              (',', '``', '[', 'morrison', '’'): 0.5100503409618338,
#              ('``', '[', 'morrison', '’', 's'): 0.5100503409618338,
#              ('[', 'morrison', '’', 's', ']'): 0.5100503409618338,
#              ('morrison', '’', 's', ']', 'narrative'): 0.5100503409618338,
#              ('’', 's', ']', 'narrative', 'voice'): 0.5100503409618338,
#              ('s', ']', 'narrative', 'voice', 'is'): 0.5100503409618338,
#              (']',
#               'narrative',
#               'voice',
#               'is',
#               'completely'): 0.5100503409618338,
#              ('narrative',
#               'voice',
#               'is',
#               'completely',
#               'original'): 0.5100503409618338,
#              ('voice',
#               'is',
#               'completely',
#               'original',
#               '.'): 0.5100503409618338,
#              ('is', 'completely', 'original', '.', 'his'): 0.5100503409618338,
#              ('completely',
#               'original',
#               '.',
#               'his',
#               'prose'): 0.5100503409618338,
#              ('original', '.', 'his', 'prose', 'feels'): 0.5100503409618338,
#              ('.', 'his', 'prose', 'feels', 'utterly'): 0.5100503409618338,
#              ('his',
#               'prose',
#               'feels',
#               'utterly',
#               'contemporary'): 0.5100503409618338,
#              ('prose',
#               'feels',
#               'utterly',
#               'contemporary',
#               ','): 0.5100503409618338,
#              ('feels',
#               'utterly',
#               'contemporary',
#               ',',
#               'with'): 0.5100503409618338,
#              ('utterly', 'contemporary', ',', 'with', 'a'): 0.5100503409618338,
#              ('contemporary', ',', 'with', 'a', 'smooth'): 0.5100503409618338,
#              (',', 'with', 'a', 'smooth', ','): 0.5100503409618338,
#              ('with', 'a', 'smooth', ',', 'readable'): 0.5100503409618338,
#              ('a', 'smooth', ',', 'readable', 'texture'): 0.5100503409618338,
#              ('smooth', ',', 'readable', 'texture', '.'): 0.5100503409618338,
#              (',', 'readable', 'texture', '.', 'it'): 0.5100503409618338,
#              ('readable', 'texture', '.', 'it', 'is'): 0.5100503409618338,
#              ('texture', '.', 'it', 'is', 'an'): 0.5100503409618338,
#              ('.', 'it', 'is', 'an', 'unusual'): 0.04770944384782329,
#              ('it', 'is', 'an', 'unusual', 'stylistic'): 0.5100503409618338,
#              ('is',
#               'an',
#               'unusual',
#               'stylistic',
#               'shorthand'): 0.5100503409618338,
#              ('an',
#               'unusual',
#               'stylistic',
#               'shorthand',
#               'as'): 0.5100503409618338,
#              ('unusual',
#               'stylistic',
#               'shorthand',
#               'as',
#               'much'): 0.5100503409618338,
#              ('stylistic',
#               'shorthand',
#               'as',
#               'much',
#               'influenced'): 0.5100503409618338,
#              ('shorthand',
#               'as',
#               'much',
#               'influenced',
#               'by'): 0.5100503409618338,
#              ('as', 'much', 'influenced', 'by', 'text'): 0.5100503409618338,
#              ('much',
#               'influenced',
#               'by',
#               'text',
#               'messaging'): 0.5100503409618338,
#              ('influenced',
#               'by',
#               'text',
#               'messaging',
#               'and'): 0.5100503409618338,
#              ('by', 'text', 'messaging', 'and', 'emails'): 0.5100503409618338,
#              ('text', 'messaging', 'and', 'emails', 'as'): 0.5100503409618338,
#              ('messaging',
#               'and',
#               'emails',
#               'as',
#               'literary'): 0.5100503409618338,
#              ('and',
#               'emails',
#               'as',
#               'literary',
#               'fiction'): 0.5100503409618338,
#              ('emails', 'as', 'literary', 'fiction', "''"): 0.5100503409618338,
#              ('as', 'literary', 'fiction', "''", '.'): 0.5100503409618338,
#              ('literary', 'fiction', "''", '.', 'the'): 0.5100503409618338,
#              ('fiction', "''", '.', 'the', 'times'): 0.5100503409618338,
#              ("''", '.', 'the', 'times', 'called'): 0.5100503409618338,
#              ('.', 'the', 'times', 'called', 'it'): 0.5100503409618338,
#              ('the', 'times', 'called', 'it', '``'): 0.5100503409618338,
#              ('times', 'called', 'it', '``', 'utterly'): 0.20159133013347097,
#              ('called',
#               'it',
#               '``',
#               'utterly',
#               'compelling'): 0.5100503409618338,
#              ('it', '``', 'utterly', 'compelling', '...'): 0.5100503409618338,
#              ('``', 'utterly', 'compelling', '...', 'on'): 0.5100503409618338,
#              ('utterly',
#               'compelling',
#               '...',
#               'on',
#               'this'): 0.5100503409618338,
#              ('compelling', '...', 'on', 'this', 'form'): 0.5100503409618338,
#              ('...', 'on', 'this', 'form', ','): 0.5100503409618338,
#              ('on', 'this', 'form', ',', 'morrison'): 0.5100503409618338,
#              ('this', 'form', ',', 'morrison', 'is'): 0.5100503409618338,
#              ('form', ',', 'morrison', 'is', 'one'): 0.5100503409618338,
#              (',', 'morrison', 'is', 'one', 'of'): 0.5100503409618338,
#              ('morrison', 'is', 'one', 'of', 'the'): 0.5100503409618338,
#              ('is', 'one', 'of', 'the', 'finest'): 0.010757457216027904,
#              ('one', 'of', 'the', 'finest', 'novelists'): 0.1677708564363163,
#              ('of',
#               'the',
#               'finest',
#               'novelists',
#               'around'): 0.5100503409618338,
#              ('the',
#               'finest',
#               'novelists',
#               'around',
#               "''"): 0.5100503409618338,
#              ('finest', 'novelists', 'around', "''", '.'): 0.5100503409618338,
#              ('novelists', 'around', "''", '.', 'however'): 0.5100503409618338,
#              ('around', "''", '.', 'however', ','): 0.5100503409618338,
#              ("''", '.', 'however', ',', 'other'): 0.07163143783625811,
#              ('.', 'however', ',', 'other', 'reviewers'): 0.3377727037826409,
#              ('however',
#               ',',
#               'other',
#               'reviewers',
#               'found'): 0.5100503409618338,
#              (',', 'other', 'reviewers', 'found', 'the'): 0.5100503409618338,
#              ('other',
#               'reviewers',
#               'found',
#               'the',
#               'book'): 0.5100503409618338,
#              ('reviewers',
#               'found',
#               'the',
#               'book',
#               'depressing'): 0.5100503409618338,
#              ('found', 'the', 'book', 'depressing', '.'): 0.5100503409618338,
#              ('the', 'book', 'depressing', '.', '``'): 0.5100503409618338,
#              ('book', 'depressing', '.', '``', 'a'): 0.5100503409618338,
#              ('depressing', '.', '``', 'a', 'death'): 0.5100503409618338,
#              ('.', '``', 'a', 'death', 'would'): 0.5100503409618338,
#              ('``', 'a', 'death', 'would', 'liven'): 0.5100503409618338,
#              ('a', 'death', 'would', 'liven', 'things'): 0.5100503409618338,
#              ('death', 'would', 'liven', 'things', 'up'): 0.5100503409618338,
#              ('would', 'liven', 'things', 'up', "''"): 0.5100503409618338,
#              ('liven', 'things', 'up', "''", ','): 0.5100503409618338,
#              ('things', 'up', "''", ',', 'said'): 0.5100503409618338,
#              ('up', "''", ',', 'said', 'the'): 0.5100503409618338,
#              ("''", ',', 'said', 'the', 'scotsman'): 0.5100503409618338,
#              (',', 'said', 'the', 'scotsman', ','): 0.5100503409618338,
#              ('said', 'the', 'scotsman', ',', '“'): 0.5100503409618338,
#              ('the', 'scotsman', ',', '“', '…too'): 0.5100503409618338,
#              ('scotsman', ',', '“', '…too', 'much'): 0.5100503409618338,
#              (',', '“', '…too', 'much', 'verbiage'): 0.5100503409618338,
#              ('“', '…too', 'much', 'verbiage', ','): 0.5100503409618338,
#              ('…too',
#               'much',
#               'verbiage',
#               ',',
#               'conversational'): 0.5100503409618338,
#              ('much',
#               'verbiage',
#               ',',
#               'conversational',
#               'psychotherapy'): 0.5100503409618338,
#              ('verbiage',
#               ',',
#               'conversational',
#               'psychotherapy',
#               "''"): 0.5100503409618338,
#              (',',
#               'conversational',
#               'psychotherapy',
#               "''",
#               '.'): 0.5100503409618338,
#              ('conversational',
#               'psychotherapy',
#               "''",
#               '.',
#               'menage'): 0.5100503409618338,
#              ('psychotherapy',
#               "''",
#               '.',
#               'menage',
#               'morrison'): 0.5100503409618338,
#              ("''", '.', 'menage', 'morrison', "'s"): 0.5100503409618338,
#              ('.', 'menage', 'morrison', "'s", 'third'): 0.5100503409618338,
#              ('menage',
#               'morrison',
#               "'s",
#               'third',
#               'novel'): 0.5100503409618338,
#              ('morrison',
#               "'s",
#               'third',
#               'novel',
#               'menage'): 0.5100503409618338,
#              ("'s", 'third', 'novel', 'menage', ','): 0.5100503409618338,
#              ('third', 'novel', 'menage', ',', 'is'): 0.5100503409618338,
#              ('novel', 'menage', ',', 'is', 'about'): 0.5100503409618338,
#              ('menage', ',', 'is', 'about', 'three'): 0.5100503409618338,
#              (',',
#               'is',
#               'about',
#               'three',
#               'dysfunctional'): 0.5100503409618338,
#              ('is',
#               'about',
#               'three',
#               'dysfunctional',
#               'artists'): 0.5100503409618338,
#              ('about',
#               'three',
#               'dysfunctional',
#               'artists',
#               'living'): 0.5100503409618338,
#              ('three',
#               'dysfunctional',
#               'artists',
#               'living',
#               'a'): 0.5100503409618338,
#              ('dysfunctional',
#               'artists',
#               'living',
#               'a',
#               'life'): 0.5100503409618338,
#              ('artists', 'living', 'a', 'life', 'of'): 0.5100503409618338,
#              ('living', 'a', 'life', 'of', 'debauched'): 0.5100503409618338,
#              ('a', 'life', 'of', 'debauched', 'squalor'): 0.5100503409618338,
#              ('life',
#               'of',
#               'debauched',
#               'squalor',
#               'within'): 0.5100503409618338,
# ...
#              ('described', 'the', 'book', 'as', 'a'): 0.5033058586089054,
#              ('the', 'book', 'as', 'a', 'partly'): 0.2524901341453254,
#              ('book',
#               'as',
#               'a',
#               'partly',
#               'autobiographical'): 0.5100503409618338,
#              ('as',
#               'a',
#               'partly',
#               'autobiographical',
#               'reaction'): 0.5100503409618338,
#              ('a',
#               'partly',
#               'autobiographical',
#               'reaction',
#               'to'): 0.5100503409618338,
#              ('partly',
#               'autobiographical',
#               'reaction',
#               'to',
#               "'coming"): 0.5100503409618338,
#              ('autobiographical',
#               'reaction',
#               'to',
#               "'coming",
#               'to'): 0.5100503409618338,
#              ('reaction', 'to', "'coming", 'to', 'terms'): 0.5100503409618338,
#              ('to', "'coming", 'to', 'terms', 'with'): 0.5100503409618338,
#              ("'coming", 'to', 'terms', 'with', 'a'): 0.5100503409618338,
#              ('to', 'terms', 'with', 'a', 'hippy'): 0.5100503409618338,
#              ('terms', 'with', 'a', 'hippy', 'childhood'): 0.5100503409618338,
#              ('with', 'a', 'hippy', 'childhood', "'"): 0.5100503409618338,
#              ('a', 'hippy', 'childhood', "'", 'and'): 0.5100503409618338,
#              ('hippy', 'childhood', "'", 'and', 'being'): 0.5100503409618338,
#              ('childhood', "'", 'and', 'being', 'raised'): 0.5100503409618338,
#              ("'", 'and', 'being', 'raised', 'by'): 0.5100503409618338,
#              ('and', 'being', 'raised', 'by', 'political'): 0.5100503409618338,
#              ('being',
#               'raised',
#               'by',
#               'political',
#               'extremists'): 0.5100503409618338,
#              ('raised',
#               'by',
#               'political',
#               'extremists',
#               '.'): 0.5100503409618338,
#              ('by',
#               'political',
#               'extremists',
#               '.',
#               'tales'): 0.5100503409618338,
#              ('political',
#               'extremists',
#               '.',
#               'tales',
#               'from'): 0.5100503409618338,
#              ('extremists', '.', 'tales', 'from', 'the'): 0.5100503409618338,
#              ('.', 'tales', 'from', 'the', 'mall'): 0.6755386522463125,
#              ('tales', 'from', 'the', 'mall', 'in'): 0.20159133013347097,
#              ('from', 'the', 'mall', 'in', 'the'): 0.5100503409618338,
#              ('the', 'mall', 'in', 'the', 'same'): 0.5100503409618338,
#              ('mall', 'in', 'the', 'same', 'year'): 0.5100503409618338,
#              ('in', 'the', 'same', 'year', 'morrison'): 0.026343609155064077,
#              ('the',
#               'same',
#               'year',
#               'morrison',
#               'published'): 0.5100503409618338,
#              ('same',
#               'year',
#               'morrison',
#               'published',
#               'tales'): 0.5100503409618338,
#              ('year',
#               'morrison',
#               'published',
#               'tales',
#               'from'): 0.5100503409618338,
#              ('morrison',
#               'published',
#               'tales',
#               'from',
#               'the'): 0.5100503409618338,
#              ('published', 'tales', 'from', 'the', 'mall'): 0.5100503409618338,
#              ('tales', 'from', 'the', 'mall', '–'): 0.201590923751774,
#              ('from', 'the', 'mall', '–', '“'): 0.5100503409618338,
#              ('the', 'mall', '–', '“', "'"): 0.5100503409618338,
#              ('mall', '–', '“', "'", 'a'): 0.5100503409618338,
#              ('–', '“', "'", 'a', 'mash-up'): 0.5100503409618338,
#              ('“', "'", 'a', 'mash-up', 'of'): 0.5100503409618338,
#              ("'", 'a', 'mash-up', 'of', 'fact'): 0.5100503409618338,
#              ('a', 'mash-up', 'of', 'fact', ','): 0.5100503409618338,
#              ('mash-up', 'of', 'fact', ',', 'fiction'): 0.5100503409618338,
#              ('of', 'fact', ',', 'fiction', ','): 0.5100503409618338,
#              ('fact', ',', 'fiction', ',', 'essays'): 0.5100503409618338,
#              (',', 'fiction', ',', 'essays', 'and'): 0.5100503409618338,
#              ('fiction',
#               ',',
#               'essays',
#               'and',
#               'multi-format'): 0.3377727037826409,
#              (',',
#               'essays',
#               'and',
#               'multi-format',
#               'media'): 0.5100503409618338,
#              ('essays',
#               'and',
#               'multi-format',
#               'media',
#               'that'): 0.5100503409618338,
#              ('and',
#               'multi-format',
#               'media',
#               'that',
#               'tells'): 0.5100503409618338,
#              ('multi-format',
#               'media',
#               'that',
#               'tells',
#               'of'): 0.5100503409618338,
#              ('media', 'that', 'tells', 'of', 'the'): 0.5100503409618338,
#              ('that', 'tells', 'of', 'the', 'rise'): 0.5100503409618338,
#              ('tells', 'of', 'the', 'rise', 'of'): 0.5100503409618338,
#              ('of', 'the', 'rise', 'of', 'the'): 0.5100503409618338,
#              ('the', 'rise', 'of', 'the', 'shopping'): 0.1677708564363163,
#              ('rise', 'of', 'the', 'shopping', 'mall'): 0.5100503409618338,
#              ('of', 'the', 'shopping', 'mall', ','): 0.5100503409618338,
#              ('the', 'shopping', 'mall', ',', 'an'): 0.5100503409618338,
#              ('shopping', 'mall', ',', 'an', 'iconic'): 0.5100503409618338,
#              ('mall', ',', 'an', 'iconic', 'symbol'): 0.5100503409618338,
#              (',', 'an', 'iconic', 'symbol', 'of'): 0.5100503409618338,
#              ('an', 'iconic', 'symbol', 'of', 'our'): 0.5100503409618338,
#              ('iconic', 'symbol', 'of', 'our', 'age'): 0.5100503409618338,
#              ('symbol', 'of', 'our', 'age', "''"): 0.5100503409618338,
#              ('of', 'our', 'age', "''", '.'): 0.5100503409618338,
#              ('our', 'age', "''", '.', 'douglas'): 0.5100503409618338,
#              ('age', "''", '.', 'douglas', 'coupland'): 0.5100503409618338,
#              ("''", '.', 'douglas', 'coupland', 'said'): 0.5100503409618338,
#              ('.', 'douglas', 'coupland', 'said', '``'): 0.5100503409618338,
#              ('douglas',
#               'coupland',
#               'said',
#               '``',
#               'morrison'): 0.5100503409618338,
#              ('coupland',
#               'said',
#               '``',
#               'morrison',
#               'continues'): 0.5100503409618338,
#              ('said',
#               '``',
#               'morrison',
#               'continues',
#               'ballard'): 0.5100503409618338,
#              ('``',
#               'morrison',
#               'continues',
#               'ballard',
#               "'s"): 0.5100503409618338,
#              ('morrison',
#               'continues',
#               'ballard',
#               "'s",
#               'tradition'): 0.5100503409618338,
#              ('continues',
#               'ballard',
#               "'s",
#               'tradition',
#               'of'): 0.5100503409618338,
#              ('ballard',
#               "'s",
#               'tradition',
#               'of',
#               'locating'): 0.5100503409618338,
#              ("'s",
#               'tradition',
#               'of',
#               'locating',
#               'menace'): 0.5100503409618338,
#              ('tradition',
#               'of',
#               'locating',
#               'menace',
#               'beneath'): 0.5100503409618338,
#              ('of',
#               'locating',
#               'menace',
#               'beneath',
#               'the'): 0.5100503409618338,
#              ('locating',
#               'menace',
#               'beneath',
#               'the',
#               'sleekness'): 0.5100503409618338,
#              ('menace',
#               'beneath',
#               'the',
#               'sleekness',
#               'and'): 0.5100503409618338,
#              ('beneath',
#               'the',
#               'sleekness',
#               'and',
#               'shine'): 0.5100503409618338,
#              ('the', 'sleekness', 'and', 'shine', 'of'): 0.5100503409618338,
#              ('sleekness', 'and', 'shine', 'of', 'post'): 0.5100503409618338,
#              ('and', 'shine', 'of', 'post', 'industrial'): 0.5100503409618338,
#              ('shine', 'of', 'post', 'industrial', 'life'): 0.5100503409618338,
#              ('of', 'post', 'industrial', 'life', '.'): 0.5100503409618338,
#              ('post', 'industrial', 'life', '.', 'a'): 0.5100503409618338,
#              ('industrial', 'life', '.', 'a', 'truly'): 0.5100503409618338,
#              ('life', '.', 'a', 'truly', 'interesting'): 0.5100503409618338,
#              ('.', 'a', 'truly', 'interesting', 'book'): 0.5100503409618338,
#              ('a', 'truly', 'interesting', 'book', "''"): 0.5100503409618338,
#              ('truly', 'interesting', 'book', "''", '.'): 0.5100503409618338,
#              ('interesting', 'book', "''", '.', 'james'): 0.5100503409618338,
#              ('book', "''", '.', 'james', 'frey'): 0.5100503409618338,
#              ("''", '.', 'james', 'frey', 'called'): 0.5100503409618338,
#              ('.', 'james', 'frey', 'called', 'it'): 0.5100503409618338,
#              ('james', 'frey', 'called', 'it', 'a'): 0.5100503409618338,
#              ('frey', 'called', 'it', 'a', '``'): 0.5100503409618338,
#              ('called', 'it', 'a', '``', 'new'): 0.10039716323449097,
#              ('it', 'a', '``', 'new', 'form'): 0.5100503409618338,
#              ('a', '``', 'new', 'form', 'of'): 0.5100503409618338,
#              ('``', 'new', 'form', 'of', 'literary'): 0.5100503409618338,
#              ('new',
#               'form',
#               'of',
#               'literary',
#               'storytelling'): 0.5100503409618338,
#              ('form',
#               'of',
#               'literary',
#               'storytelling',
#               "''"): 0.5100503409618338,
#              ('of', 'literary', 'storytelling', "''", '.'): 0.5100503409618338,
#              ('literary',
#               'storytelling',
#               "''",
#               '.',
#               'irvine'): 0.5100503409618338,
#              ('storytelling',
#               "''",
#               '.',
#               'irvine',
#               'welsh'): 0.5100503409618338,
#              ("''", '.', 'irvine', 'welsh', 'called'): 0.5100503409618338,
#              ('.', 'irvine', 'welsh', 'called', 'it'): 0.5100503409618338,
#              ('irvine', 'welsh', 'called', 'it', '``'): 0.5100503409618338,
#              ('welsh', 'called', 'it', '``', 'truly'): 0.5100503409618338,
#              ('called', 'it', '``', 'truly', 'zeitgeist'): 0.5100503409618338,
#              ('it', '``', 'truly', 'zeitgeist', 'writing'): 0.5100503409618338,
#              ('``', 'truly', 'zeitgeist', 'writing', "''"): 0.5100503409618338,
#              ('truly', 'zeitgeist', 'writing', "''", '.'): 0.5100503409618338,
#              ('zeitgeist', 'writing', "''", '.', 'tales'): 0.5100503409618338,
#              ('writing', "''", '.', 'tales', 'from'): 0.5100503409618338,
#              ("''", '.', 'tales', 'from', 'the'): 0.5100503409618338,
#              ('tales', 'from', 'the', 'mall', 'won'): 0.20159051737171546,
#              ('from', 'the', 'mall', 'won', 'the'): 0.5100503409618338,
#              ('the', 'mall', 'won', 'the', 'guardian'): 0.5100503409618338,
#              ('mall', 'won', 'the', 'guardian', 'not'): 0.5100503409618338,
#              ('won', 'the', 'guardian', 'not', 'the'): 0.5100503409618338,
#              ('the', 'guardian', 'not', 'the', 'booker'): 0.5100503409618338,
#              ('guardian', 'not', 'the', 'booker', 'prize'): 0.5100503409618338,
#              ('not', 'the', 'booker', 'prize', 'in'): 0.5100503409618338,
#              ('the', 'booker', 'prize', 'in', '2012'): 0.5100503409618338,
#              ('booker', 'prize', 'in', '2012', 'and'): 0.5100503409618338,
#              ('prize', 'in', '2012', 'and', 'was'): 0.5100503409618338,
#              ('in', '2012', 'and', 'was', 'a'): 0.5100503409618338,
#              ('2012', 'and', 'was', 'a', 'finalist'): 0.5100503409618338,
#              ('and', 'was', 'a', 'finalist', 'in'): 0.3377727037826409,
#              ('was', 'a', 'finalist', 'in', 'the'): 0.5100503409618338,
#              ('a', 'finalist', 'in', 'the', 'saltire'): 0.3377727037826409,
#              ('finalist',
#               'in',
#               'the',
#               'saltire',
#               'society'): 0.5100503409618338,
#              ('in', 'the', 'saltire', 'society', 'book'): 0.5100503409618338,
#              ('the', 'saltire', 'society', 'book', 'of'): 0.5100503409618338,
#              ('saltire', 'society', 'book', 'of', 'the'): 0.5100503409618338,
#              ('society', 'book', 'of', 'the', 'year'): 0.5100503409618338,
#              ('book', 'of', 'the', 'year', 'award'): 0.1256205531213571,
#              ('of', 'the', 'year', 'award', 'and'): 0.07163133521719979,
#              ('the', 'year', 'award', 'and', 'the'): 0.5100503409618338,
#              ('year', 'award', 'and', 'the', 'creative'): 0.5100503409618338,
#              ('award',
#               'and',
#               'the',
#               'creative',
#               'scotland'): 0.5100503409618338,
#              ('and',
#               'the',
#               'creative',
#               'scotland',
#               'writer'): 0.5100503409618338,
#              ('the',
#               'creative',
#               'scotland',
#               'writer',
#               'of'): 0.5100503409618338,
#              ('creative',
#               'scotland',
#               'writer',
#               'of',
#               'the'): 0.5100503409618338,
#              ('scotland', 'writer', 'of', 'the', 'year'): 0.5100503409618338,
#              ('the', 'year', 'award', 'in', 'the'): 0.3377715629053178,
#              ('year', 'award', 'in', 'the', 'same'): 0.5100503409618338,
#              ('award', 'in', 'the', 'same', 'year'): 0.5100503409618338,
#              ('in', 'the', 'same', 'year', '.'): 0.13171590363070798,
#              ('the', 'same', 'year', '.', 'nina'): 0.06684344175345558,
#              ('same', 'year', '.', 'nina', 'x'): 0.5100503409618338,
#              ('year', '.', 'nina', 'x', 'morrison'): 0.5100503409618338,
#              ('.', 'nina', 'x', 'morrison', "'s"): 0.5100503409618338,
#              ('nina', 'x', 'morrison', "'s", 'seventh'): 0.5100503409618338,
#              ('x', 'morrison', "'s", 'seventh', 'book'): 0.5100503409618338,
#              ('morrison', "'s", 'seventh', 'book', 'of'): 0.5100503409618338,
#              ("'s", 'seventh', 'book', 'of', 'fiction'): 0.5100503409618338,
#              ('seventh', 'book', 'of', 'fiction', ','): 0.5100503409618338,
#              ('book', 'of', 'fiction', ',', 'nina'): 0.5100503409618338,
#              ('of', 'fiction', ',', 'nina', 'x'): 0.5100503409618338,
#              ('fiction', ',', 'nina', 'x', ','): 0.5100503409618338,
#              (',', 'nina', 'x', ',', 'was'): 0.3377715629053178,
#              ('nina', 'x', ',', 'was', 'published'): 0.5100503409618338,
#              ('x', ',', 'was', 'published', 'by'): 0.5100503409618338,
#              (',', 'was', 'published', 'by', 'fleet'): 0.09123745624111024,
#              ('was', 'published', 'by', 'fleet', ','): 0.5100503409618338,
#              ('published', 'by', 'fleet', ',', 'an'): 0.5100503409618338,
#              ('by', 'fleet', ',', 'an', 'imprint'): 0.5100503409618338,
#              ('fleet', ',', 'an', 'imprint', 'of'): 0.5100503409618338,
#              (',', 'an', 'imprint', 'of', 'little'): 0.5100503409618338,
#              ('an', 'imprint', 'of', 'little', 'brown'): 0.5100503409618338,
#              ('imprint', 'of', 'little', 'brown', ','): 0.5100503409618338,
#              ('of', 'little', 'brown', ',', 'on'): 0.5100503409618338,
#              ('little', 'brown', ',', 'on', '4'): 0.5100503409618338,
#              ('brown', ',', 'on', '4', 'april'): 0.5100503409618338,
#              ...})

# %%
print('These are the top 10 n-grams:')
sorted(ngram_prob, key=ngram_prob.get, reverse=True)[:10]
# Out:
# These are the top 10 n-grams:
# [('style=', "''", 'background', ':', '#'),
#  ('background', ':', '#', 'f2f2f2', "''"),
#  ('|', 'style=', "''", 'background', ':'),
#  ('of', 'birth', 'missing', '(', 'living'),
#  ('birth', 'missing', '(', 'living', 'people'),
#  ('missing', '(', 'living', 'people', ')'),
#  ("''", 'text-align', ':', 'center', ';'),
#  ('games', 'video', 'games', 'developed', 'in'),
#  ('style=', "''", 'text-align', ':', 'center'),
#  ('|', 'style=', "''", 'text-align', ':')]

# %% [markdown]
# ## Perplexity

# %%
def calculate_perplexity(test_tokens, ngram_probabilities, n):
    """Calculates the perplexity of a test corpus given n-gram probabilities."""
    log_probability_sum = 0
    ngram_count = 0
    
    for i in range(len(test_tokens)-n+1):
        ngram = tuple(test_tokens[i:i+n])
        log_probability_sum += math.log2(ngram_probabilities[ngram])
        ngram_count += 1
    
    average_log_probability = -log_probability_sum / ngram_count
    perplexity = math.pow(2, average_log_probability)
    
    return perplexity

# %%
calculate_perplexity(train_tokens, ngram_prob, n)
# Out:
# 2.089571549447328

# %%
calculate_perplexity(test_tokens, ngram_prob, n)
# Out:
# 37547.20650358416

# %%
def greedy_sampling(context, vocab, ngram_probabilities, n, max_length = 50):
    
    sentence = []

    if len(context) < (n-1):
        print("len(context) < n")
        return sentence

    context = context[-(n-1):]
    
    for i in range(max_length):

        probs = dict()
        
        for v in vocab:

            ngram = list(context)
            ngram.append(v)
            ngram = tuple(ngram)
            probs[v] = ngram_probabilities[ngram]

        best_token = max(probs, key=probs.get) # greedy 
        #print(best_token)
        #print(probs[best_token])
        
        if probs[best_token] == 0:
            print("prob = 0")
            return sentence
            
        sentence.append(best_token)
        context = list(context)[1:]
        context.append(best_token)
        context = tuple(context)
            
    return sentence

# %%
context = ['he', 'was', 'the', 'first']
sentence = greedy_sampling(context, vocab, ngram_prob, 5, max_length=200)
print(" ".join(context) + " " +  " ".join(sentence))
# Out:
# he was the first to be released for the playstation 2 , gamecube , xbox and microsoft windows . later on , in 2003 , then president thabo mbeki conferred , post-humously , the order of luthuli to winnie kgware for outstanding leadership and lifelong commitment to the ideals of democracy , non-racialism , peace and justice . see also south african history online black consciousness movement external links the presidency steve biko foundation references 1917 births 1998 deaths south african activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african women activists south african

# %% [markdown]
# ## Interpolation
# Mixing different sizes of n-grams

# %%
n = 5
ngram_prob_interpol = {}

for i in range(2, n+1):
    new_ngram = calculate_ngram_probabilities(train_tokens, i, test_tokens)
    ngram_prob_interpol = ngram_prob_interpol | new_ngram
    print(f"Number of {i}-grams:", len(new_ngram))
# Out:
# Number of 2-grams: 832711
# Number of 3-grams: 1662980
# Number of 4-grams: 2048125
# Number of 5-grams: 2173586

# %%
print('These are the top 10 n-grams (using interpolation):')
sorted(ngram_prob_interpol, key=ngram_prob_interpol.get, reverse=True)[:10]
# Out:
# These are the top 10 n-grams (using interpolation):
# [('according', 'to'),
#  ('style=', "''"),
#  ('.', 'according', 'to'),
#  ('births', 'living', 'people'),
#  ('references', 'external', 'links'),
#  ('|', 'style=', "''"),
#  ('background', ':', '#'),
#  ("''", 'background', ':', '#'),
#  ('style=', "''", 'background', ':'),
#  ('style=', "''", 'background', ':', '#')]

# %%
def greedy_sampling_interpol(context, vocab, ngram_probabilities, n, max_length = 50):
    
    sentence = []

    if len(context) < (n-1):
        print("len(context) < n")
        return sentence

    context = context[-(n-1):]
    
    for i in range(max_length):

        probs = dict()

        for i in range(1, n): 
            for v in vocab:
                ngram = list(context[(i-1):])
                ngram.append(v)
                ngram = tuple(ngram)
                if v in probs:
                    probs[v] += ngram_probabilities[ngram] / n
                else:
                    probs[v] = ngram_probabilities[ngram] / n

        best_token = max(probs, key=probs.get) # greedy 
        #print(best_token)
        #print(probs[best_token])
        
        if probs[best_token] == 0:
            print("prob = 0")
            return sentence
            
        sentence.append(best_token)
        context = list(context)[1:]
        context.append(best_token)
        context = tuple(context)
            
    return sentence

# %%
context = ['he', 'was', 'the', 'first']
sentence = greedy_sampling_interpol(context, vocab, ngram_prob_interpol, n, max_length=200)
print(" ".join(context) + " " +  " ".join(sentence))
# Out:
# he was the first to be released for the playstation 2 , xbox 360 and playstation 3 versions were released by electronic arts in japan on december 10 , 2015. marvelous usa published the game in north america , and is the only one of the ten to whom paradise was promised . background his parents were both from the zuhra clan of the quraysh in mecca . salim the elder ( died before islam ) . the daughter of the french painter pierre auguste cot , the most notable of these is methane clathrate , 4 , naturally found in large quantities of the same name . the game was released on the same day . the game was released on the same day . the game was released on the same day . the game was released on the same day . the game was released on the same day . the game was released on the same day . the game was released on the same day . the game was released on the same day . the game was released on the same day . the game was released on the same day . the game was released on the
