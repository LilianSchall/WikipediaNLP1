# %%
from datasets import load_dataset
import pandas as pd
import requests

WIKIPEDIA_URL = "https://en.wikipedia.org/w/api.php"
session = requests.Session()

# %%
dataset = load_dataset("wikipedia", "20220301.en")
# Out:
# /home/lilian/Documents/SCIA/WikipediaNLP1/venv/lib/python3.11/site-packages/datasets/load.py:1461: FutureWarning: The repository for wikipedia contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/wikipedia
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %%
len(dataset["train"])
# Out:
# 6458670

# %%
dataset = dataset["train"]

# %%
def load_dataframe(shard_index: int):
    shard = dataset.shard(30, shard_index)
    return pd.DataFrame(shard)

# %%
df_wikipedia = load_dataframe(0)

# %%
df_wikipedia
# Out:
#               id                                                url  \
# 0             12            https://en.wikipedia.org/wiki/Anarchism
# 1            597  https://en.wikipedia.org/wiki/Austroasiatic%20...
# 2            666       https://en.wikipedia.org/wiki/Alkali%20metal
# 3            734       https://en.wikipedia.org/wiki/Actinopterygii
# 4            795            https://en.wikipedia.org/wiki/Affidavit
# ...          ...                                                ...
# 215284  70198872    https://en.wikipedia.org/wiki/Sunny%20Prajapati
# 215285  70199540  https://en.wikipedia.org/wiki/2022%20British%2...
# 215286  70200137  https://en.wikipedia.org/wiki/Geertruida%20H.%...
# 215287  70200675  https://en.wikipedia.org/wiki/Sceloporus%20coz...
# 215288  70201352  https://en.wikipedia.org/wiki/Illuminators%20%...
#
#                                               title  \
# 0                                         Anarchism
# 1                           Austroasiatic languages
# 2                                      Alkali metal
# 3                                    Actinopterygii
# 4                                         Affidavit
# ...                                             ...
# 215284                              Sunny Prajapati
# 215285  2022 British Indoor Athletics Championships
# 215286                       Geertruida H. Springer
# 215287                         Sceloporus cozumelae
# 215288                         Illuminators (album)
#
#                                                      text
# 0       Anarchism is a political philosophy and moveme...
# 1       The Austroasiatic languages , also known as Mo...
# 2       The alkali metals consist of the chemical elem...
# 3       Actinopterygii (; ), members of which are know...
# 4       An  ( ; Medieval Latin for "he has declared un...
# ...                                                   ...
# 215284  Sunny Prajapati (born 25 December 1995) is an ...
# 215285  The 2022 British Indoor Athletics Championship...
# 215286  Geertruida H. Springer (1895 – 1988) was a Dut...
# 215287  Sceloporus cozumelae, the  Cozumel spiny lizar...
# 215288  Illuminators is a live album by drummer Sunny ...
#
# [215289 rows x 4 columns]

# %%
df_wikipedia["title"].iloc[0]
# Out:
# 'Anarchism'

# %%
def search_categories(title: str):
    params = {
    "action": "query",
    "format": "json",
    "prop": "categories",
    "cllimit": "max",
    "clshow": "!hidden",
    "titles": title
    }
    response = session.get(url=WIKIPEDIA_URL, params=params)
    json_response = response.json()
    pages = json_response["query"]["pages"]
    
    categories = []
    
    for k, v in pages.items():
        cats = v.get("categories")
        if cats is None:
            continue
        for category in cats:
            categories.append(category["title"])
    print("Processed", title)
    return categories

# %%
def build_hashmap(df, nb_rows):
    categories_hashmap = {}
    for i in range(nb_rows):
        title = df["title"].iloc[i]
        categories_list = search_categories(title)
        for cat in categories_list:
            categories_hashmap[cat] = categories_hashmap[cat] + 1 if categories_hashmap.get(cat) is not None else 1
        #if (i % 10 == 0):
            #print(i)
    return categories_hashmap

# %%
hashmap = build_hashmap(df_wikipedia, 1000)
# Out:
# Processed Anarchism
# Processed Austroasiatic languages
# Processed Alkali metal
# Processed Actinopterygii
# Processed Affidavit
# Processed Ancient Egypt
# Processed A. A. Milne
# Processed August
# Processed André Gide
# Processed Abbot
# Processed Angle
# Processed April 26
# Processed Arabian Prince
# Processed Army
# Processed Absalom
# Processed Albert
# Processed Agesilaus II
# Processed Alexander of Pherae
# Processed August 23
# Processed Alfonso XII
# Processed Ambrosius Aurelianus
# Processed Andronikos II Palaiologos
# Processed Actium
# Processed Aimery of Cyprus
# Processed Argo Navis
# Processed Apollo 12
# Processed Atle Selberg
# Processed Aeronautics
# Processed Ani DiFranco
# Processed Arcadius
# Processed Afghans
# Processed August 10
# Processed Albert Pike
# Processed Albrecht Achilles
# Processed April 21
# Processed Ab urbe condita
# Processed Aedicula
# Processed Abd al-Latif al-Baghdadi
# Processed Abersychan
# Processed ACE inhibitor
# Processed Antigonid dynasty
# Processed Amoxicillin
# Processed Ariel Sharon
# Processed Ann Druyan
# Processed Aimaq people
# Processed Agra Canal
# Processed Attribution of recent climate change
# Processed Agar
# Processed Bach (disambiguation)
# Processed Bromeliales
# Processed Government of Barbados
# Processed Transport in Brazil
# Processed Communications in Burundi
# Processed Bill Gates
# Processed Hit by pitch
# Processed American League Division Series
# Processed Baroque
# Processed Bing Crosby
# Processed Brittonic languages
# Processed Branco River
# Processed Bunsen
# Processed Barcelonnette
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 hashmap = build_hashmap(df_wikipedia, 1000)
#
# Cell In[10], line 5, in build_hashmap(df, nb_rows)
#       3 for i in range(nb_rows):
#       4     title = df["title"].iloc[i]
# ----> 5     categories_list = search_categories(title)
#       6     for cat in categories_list:
#       7         categories_hashmap[cat] = categories_hashmap[cat] + 1 if categories_hashmap.get(cat) is not None else 1
#
# Cell In[9], line 10, in search_categories(title)
#       1 def search_categories(title: str):
#       2     params = {
#       3     "action": "query",
#       4     "format": "json",
#    (...)
#       8     "titles": title
#       9     }
# ---> 10     response = session.get(url=WIKIPEDIA_URL, params=params)
#      11     json_response = response.json()
#      12     pages = json_response["query"]["pages"]
#
# File ~/Documents/SCIA/WikipediaNLP1/venv/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/Documents/SCIA/WikipediaNLP1/venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/SCIA/WikipediaNLP1/venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/SCIA/WikipediaNLP1/venv/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/Documents/SCIA/WikipediaNLP1/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/Documents/SCIA/WikipediaNLP1/venv/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/SCIA/WikipediaNLP1/venv/lib/python3.11/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /nix/store/qp5zys77biz7imbk6yy85q5pdv7qk84j-python3-3.11.6/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /nix/store/qp5zys77biz7imbk6yy85q5pdv7qk84j-python3-3.11.6/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /nix/store/qp5zys77biz7imbk6yy85q5pdv7qk84j-python3-3.11.6/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /nix/store/qp5zys77biz7imbk6yy85q5pdv7qk84j-python3-3.11.6/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /nix/store/qp5zys77biz7imbk6yy85q5pdv7qk84j-python3-3.11.6/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /nix/store/qp5zys77biz7imbk6yy85q5pdv7qk84j-python3-3.11.6/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
sorted_hashmap = dict(reversed(sorted(hashmap.items(), key=lambda item: item[1])))

# %%
sorted_hashmap
# Out:
# {'Category:Disambiguation pages': 72,
#  'Category:Living people': 35,
#  'Category:Days of the year': 16,
#  'Category:Place name disambiguation pages': 11,
#  'Category:20th-century American male writers': 10,
#  'Category:American people of English descent': 10,
#  'Category:American male non-fiction writers': 9,
#  'Category:Members of the American Philosophical Society': 8,
#  'Category:Fellows of the Royal Society': 7,
#  'Category:American male screenwriters': 6,
#  'Category:American male novelists': 6,
#  'Category:21st-century American male writers': 6,
#  'Category:Columbia Records artists': 6,
#  'Category:American people of Scottish descent': 6,
#  'Category:20th-century American novelists': 6,
#  'Category:20th-century American male musicians': 5,
#  'Category:Philosophers of science': 5,
#  'Category:American Nobel laureates': 5,
#  'Category:Fellows of the American Academy of Arts and Sciences': 5,
#  'Category:Chemical elements': 5,
#  'Category:Decca Records artists': 5,
#  'Category:American male film actors': 5,
#  'Category:American people of German descent': 5,
#  'Category:Disambiguation pages with surname-holder lists': 5,
#  'Category:Hugo Award-winning writers': 5,
#  'Category:21st-century American Jews': 5,
#  'Category:1928 births': 5,
#  'Category:Grammy Award winners': 5,
#  'Category:United States National Film Registry films': 4,
#  'Category:Telecommunications stubs': 4,
#  'Category:Films whose editor won the Best Film Editing Academy Award': 4,
#  'Category:Centuries': 4,
#  'Category:Leap years in the Gregorian calendar': 4,
#  'Category:Tony Award winners': 4,
#  'Category:1990s English-language films': 4,
#  'Category:1990s American films': 4,
#  'Category:American male poets': 4,
#  'Category:1963 births': 4,
#  'Category:American male essayists': 4,
#  'Category:20th-century American non-fiction writers': 4,
#  'Category:20th-century American essayists': 4,
#  'Category:20th-century short story writers': 4,
#  'Category:20th-century American philosophers': 4,
#  'Category:Knights Bachelor': 4,
#  'Category:American male short story writers': 4,
#  'Category:21st-century American novelists': 4,
#  'Category:American science fiction writers': 4,
#  'Category:American people of French descent': 4,
#  'Category:20th-century American screenwriters': 4,
#  'Category:Hall of Fame for Great Americans inductees': 4,
#  'Category:American people of Irish descent': 4,
#  'Category:American male jazz musicians': 4,
#  'Category:20th-century American male actors': 4,
#  'Category:Presidential Medal of Freedom recipients': 4,
#  'Category:Harvard College alumni': 4,
#  'Category:American agnostics': 4,
#  'Category:20th-century American Jews': 4,
#  'Category:Latin words and phrases': 4,
#  'Category:American Freemasons': 4,
#  'Category:20th-century American mathematicians': 4,
#  'Category:Alumni of Trinity College, Cambridge': 4,
#  'Category:New York (state) counties': 3,
#  'Category:Political terminology': 3,
#  'Category:Films whose art director won the Best Art Direction Academy Award': 3,
#  'Category:Best Picture Academy Award winners': 3,
#  'Category:Digital electronics': 3,
#  'Category:Films whose cinematographer won the Best Cinematography Academy Award': 3,
#  'Category:American television actresses': 3,
#  'Category:American film actresses': 3,
#  'Category:21st-century American actresses': 3,
#  'Category:20th-century American actresses': 3,
#  'Category:General topology': 3,
#  'Category:Gases': 3,
#  'Category:Chemical properties': 3,
#  'Category:Laurence Olivier Award winners': 3,
#  'Category:Drama Desk Award winners': 3,
#  'Category:Trigonal minerals': 3,
#  'Category:Films shot in California': 3,
#  'Category:Films set in Egypt': 3,
#  'Category:21st-century American non-fiction writers': 3,
#  'Category:Medicinal plants': 3,
#  'Category:Edgar Award winners': 3,
#  'Category:Heads of government who were later imprisoned': 3,
#  'Category:1943 births': 3,
#  'Category:Recipients of the Legion of Honour': 3,
#  'Category:Popes': 3,
#  'Category:Italian popes': 3,
#  'Category:American tax resisters': 3,
#  'Category:Aluminium minerals': 3,
#  'Category:Hipparcos objects': 3,
#  'Category:Henry Draper Catalogue objects': 3,
#  'Category:Flamsteed objects': 3,
#  'Category:Durchmusterung objects': 3,
#  'Category:Bayer objects': 3,
#  'Category:Writers from Chicago': 3,
#  'Category:United States Army soldiers': 3,
#  'Category:American autobiographers': 3,
#  'Category:Foreign Members of the Royal Society': 3,
#  'Category:British Nobel laureates': 3,
#  'Category:Foreign associates of the National Academy of Sciences': 3,
#  'Category:2004 deaths': 3,
#  'Category:University of Chicago faculty': 3,
#  'Category:Philosophers of mind': 3,
#  'Category:1859 births': 3,
#  'Category:Video game development companies': 3,
#  'Category:Pseudoscience': 3,
#  'Category:World Fantasy Award-winning writers': 3,
#  'Category:Weird fiction writers': 3,
#  'Category:American male television writers': 3,
#  'Category:20th-century American short story writers': 3,
#  'Category:1948 births': 3,
#  'Category:Congressional Gold Medal recipients': 3,
#  'Category:21st-century American screenwriters': 3,
#  'Category:1944 births': 3,
#  'Category:Capitals of former nations': 3,
#  'Category:Founding monarchs': 3,
#  'Category:Telegraphy': 3,
#  'Category:Inkpot Award winners': 3,
#  'Category:20th-century American writers': 3,
#  'Category:Commandeurs of the Ordre des Arts et des Lettres': 3,
#  'Category:Spanish-speaking countries and territories': 3,
#  'Category:Member states of the United Nations': 3,
#  'Category:Former Spanish colonies': 3,
#  'Category:Christian terminology': 3,
#  'Category:Cross-platform software': 3,
#  'Category:American people of Welsh descent': 3,
#  'Category:1936 births': 3,
#  'Category:Subprefectures in France': 3,
#  'Category:Grammy Lifetime Achievement Award winners': 3,
#  'Category:Art movements': 3,
#  'Category:American technology writers': 3,
#  'Category:21st-century American businesspeople': 3,
#  'Category:20th-century American businesspeople': 3,
#  'Category:Broadcast call sign disambiguation pages': 3,
#  'Category:E-number additives': 3,
#  'Category:1949 births': 3,
#  'Category:Jewish agnostics': 3,
#  'Category:Deaths from kidney failure': 3,
#  'Category:2014 deaths': 3,
#  'Category:American people of Italian descent': 3,
#  'Category:American atheists': 3,
#  'Category:Activists from New York (state)': 3,
#  'Category:20th-century American guitarists': 3,
#  'Category:Constellations listed by Ptolemy': 3,
#  'Category:Grand Crosses of the Order of Saint Stephen of Hungary': 3,
#  'Category:Nobel laureates in Literature': 3,
#  'Category:August': 3,
#  'Category:People educated at Westminster School, London': 3,
#  'Category:English male novelists': 3,
#  'Category:20th-century English novelists': 3,
#  'Category:Lists of diseases': 2,
#  'Category:American novels adapted into films': 2,
#  'Category:Adirondacks': 2,
#  'Category:Jewish Canadian writers': 2,
#  'Category:Fellows of the American Institute of Architects': 2,
#  'Category:Fiction about near-Earth asteroids': 2,
#  'Category:Paramount Pictures films': 2,
#  'Category:Films shot in Hertfordshire': 2,
#  'Category:Films about treasure hunting': 2,
#  'Category:American action adventure films': 2,
#  'Category:1999 establishments in the United States': 2,
#  'Category:MIRV capable missiles': 2,
#  'Category:1914 births': 2,
#  'Category:Chaos theorists': 2,
#  'Category:American Presbyterians': 2,
#  'Category:Recipients of the Order of the White Eagle (Poland)': 2,
#  'Category:Logic families': 2,
#  'Category:Recipients of the Navy Distinguished Service Medal': 2,
#  'Category:Fortified settlements': 2,
#  'Category:United States county name disambiguation pages': 2,
#  'Category:Brit Award winners': 2,
#  'Category:Films shot in Europe': 2,
#  'Category:Films set in Greece': 2,
#  'Category:Films set in New York City': 2,
#  'Category:1970s English-language films': 2,
#  'Category:1970s American films': 2,
#  'Category:Urban legends': 2,
#  'Category:2001 deaths': 2,
#  'Category:Films set in Paris': 2,
#  'Category:BC year stubs': 2,
#  'Category:Underwater diving physics': 2,
#  'Category:American anarchists': 2,
#  'Category:1862 deaths': 2,
#  'Category:Princeton University faculty': 2,
#  'Category:Members of the American Academy of Arts and Letters': 2,
#  'Category:2019 deaths': 2,
#  'Category:Economic history of the United States': 2,
#  'Category:Gulfs of the Atlantic Ocean': 2,
#  'Category:Films whose director won the Best Directing Academy Award': 2,
#  'Category:Films featuring a Best Supporting Actress Academy Award-winning performance': 2,
#  'Category:Best Drama Picture Golden Globe winners': 2,
#  'Category:American black-and-white films': 2,
#  'Category:Linear algebra': 2,
#  'Category:United States communications regulation': 2,
#  'Category:Male musical theatre composers': 2,
#  'Category:Broadway composers and lyricists': 2,
#  'Category:Data transmission': 2,
#  'Category:Multiplexing': 2,
#  'Category:Telephony signals': 2,
#  'Category:Embedded systems': 2,
#  'Category:Documents of the Second Vatican Council': 2,
#  'Category:2nd millennium BC': 2,
#  'Category:Warner Bros. films': 2,
#  'Category:Films whose director won the Best Director Golden Globe': 2,
#  'Category:Films set in Washington, D.C.': 2,
#  'Category:Films scored by John Williams': 2,
#  'Category:Cultural depictions of Lee Harvey Oswald': 2,
#  'Category:Optical quantities': 2,
#  'Category:Independent Spirit Award for Best Female Lead winners': 2,
#  'Category:Harvard University alumni': 2,
#  'Category:1799 births': 2,
#  'Category:Science fiction novels adapted into films': 2,
#  'Category:Ballistic missiles': 2,
#  'Category:French male non-fiction writers': 2,
#  'Category:Academic staff of the University of Paris': 2,
#  'Category:Chemical bonding': 2,
#  'Category:American female models': 2,
#  'Category:21st-century American women writers': 2,
#  'Category:1971 births': 2,
#  'Category:Films about nuclear war and weapons': 2,
#  'Category:Cold War films': 2,
#  'Category:British black-and-white films': 2,
#  'Category:1960s English-language films': 2,
#  'Category:1960s British films': 2,
#  'Category:Writers from New York City': 2,
#  'Category:Monarchs taken prisoner in wartime': 2,
#  'Category:Telecommunications engineering': 2,
#  'Category:Integrated circuits': 2,
#  'Category:16th-century English women': 2,
#  'Category:Countries in Africa': 2,
#  'Category:Deaths from cancer in England': 2,
#  'Category:21st-century American male musicians': 2,
#  'Category:Voting theorists': 2,
#  'Category:Fictional military personnel in films': 2,
#  'Category:Fictional commanders': 2,
#  'Category:NMDA receptor antagonists': 2,
#  'Category:Hazardous air pollutants': 2,
#  'Category:Soviet Union–United States relations': 2,
#  'Category:Presidency of Dwight D. Eisenhower': 2,
#  'Category:Writers Guild of America Award winners': 2,
#  'Category:Writers who illustrated their own writing': 2,
#  'Category:University of Paris alumni': 2,
#  'Category:Naturalised citizens of the United Kingdom': 2,
#  'Category:Members of the Order of Merit': 2,
#  'Category:Lecturers': 2,
#  'Category:Ivor Novello Award winners': 2,
#  'Category:Institute for Advanced Study visiting scholars': 2,
#  'Category:American male dramatists and playwrights': 2,
#  'Category:20th-century American dramatists and playwrights': 2,
#  'Category:Superhard materials': 2,
#  'Category:Oxide minerals': 2,
#  'Category:Minerals in space group 167': 2,
#  'Category:Corundum gemstones': 2,
#  'Category:Electronic design': 2,
#  'Category:Super Bowl': 2,
#  'Category:Physiographic provinces': 2,
#  'Category:Works of unknown authorship': 2,
#  'Category:MacArthur Fellows': 2,
#  'Category:Black Lion Records artists': 2,
#  'Category:United Artists films': 2,
#  'Category:Films based on multiple works': 2,
#  'Category:1970s Italian films': 2,
#  'Category:1970s Italian-language films': 2,
#  'Category:Metro-Goldwyn-Mayer films': 2,
#  'Category:Films adapted into television shows': 2,
#  'Category:Films about archaeology': 2,
#  'Category:American space adventure films': 2,
#  'Category:American science fiction action films': 2,
#  'Category:1990s science fiction action films': 2,
#  'Category:Fictional military strategists': 2,
#  'Category:Writers about activism and social change': 2,
#  'Category:American opinion journalists': 2,
#  'Category:20th-century American poets': 2,
#  'Category:21st-century American poets': 2,
#  'Category:Corresponding Fellows of the British Academy': 2,
#  'Category:States of Germany': 2,
#  'Category:Time Person of the Year': 2,
#  'Category:People stripped of honorary degrees': 2,
#  'Category:New York (state) Republicans': 2,
#  'Category:American writers of Italian descent': 2,
#  'Category:Princeton University alumni': 2,
#  'Category:Nobel laureates affiliated with Missouri': 2,
#  'Category:Austro-Hungarian military personnel of World War I': 2,
#  'Category:1880 births': 2,
#  'Category:Subshrubs': 2,
#  'Category:Mediterranean cuisine': 2,
#  'Category:Herbs': 2,
#  'Category:Flora of the Mediterranean Basin': 2,
#  'Category:César Honorary Award recipients': 2,
#  'Category:Best Screenplay Golden Globe winners': 2,
#  'Category:Best Original Screenplay Academy Award winners': 2,
#  'Category:American film directors': 2,
#  'Category:Spirituality': 2,
#  'Category:Superscalar microprocessors': 2,
#  'Category:1953 births': 2,
#  'Category:Carnivorans of Europe': 2,
#  'Category:Password authentication': 2,
#  'Category:Leaders who took power by coup': 2,
#  'Category:Philosophy of language literature': 2,
#  'Category:Books by Ludwig Wittgenstein': 2,
#  'Category:Analytic philosophy literature': 2,
#  'Category:Quantum mechanics': 2,
#  'Category:Postmodern novels': 2,
#  'Category:Social philosophers': 2,
#  'Category:Science fiction critics': 2,
#  'Category:Postmodern writers': 2,
#  'Category:Political philosophers': 2,
#  'Category:Philosophers of love': 2,
#  'Category:Philosophers of history': 2,
#  'Category:Philosophers of culture': 2,
#  'Category:Philosophers from California': 2,
#  'Category:Counterculture of the 1960s': 2,
#  'Category:American psychological fiction writers': 2,
#  'Category:American Episcopalians': 2,
#  'Category:Source code': 2,
#  'Category:English people of French descent': 2,
#  'Category:Poetic forms': 2,
#  'Category:1888 births': 2,
#  'Category:Epic Records artists': 2,
#  'Category:Black comedy': 2,
#  'Category:Evolutionary biology': 2,
#  'Category:November': 2,
#  'Category:Transition metals': 2,
#  'Category:Stars with proper names': 2,
#  'Category:Bright Star Catalogue objects': 2,
#  'Category:Oil companies of the United States': 2,
#  'Category:Gas stations in the United States': 2,
#  'Category:Automotive fuel retailers': 2,
#  'Category:Thermodynamics': 2,
#  'Category:Phase transitions': 2,
#  'Category:Materials science': 2,
#  'Category:Medical volunteerism': 2,
#  'Category:Mechanical quantities': 2,
#  'Category:1863 births': 2,
#  'Category:March': 2,
#  'Category:Modernism': 2,
#  'Category:Virgin Records artists': 2,
#  'Category:V2 Records artists': 2,
#  'Category:Fontana Records artists': 2,
#  'Category:American veganism activists': 2,
#  'Category:Urban districts of Bavaria': 2,
#  'Category:Cities in Bavaria': 2,
#  'Category:Illeists': 2,
#  'Category:American male television actors': 2,
#  'Category:21st-century American male actors': 2,
#  'Category:Chemical elements with face-centered cubic structure': 2,
#  'Category:Antiseptics': 2,
#  'Category:1982 deaths': 2,
#  'Category:Austrian male novelists': 2,
#  'Category:Regions of Michigan': 2,
#  'Category:Jewish American scientists': 2,
#  'Category:Kings of Dál Riata': 2,
#  'Category:Gaelic monarchs in Scotland': 2,
#  'Category:Citrus': 2,
#  'Category:Extreme programming': 2,
#  'Category:Mechanical engineering': 2,
#  'Category:Nobel laureates in Chemistry': 2,
#  'Category:English Nobel laureates': 2,
#  'Category:Ghost story writers': 2,
#  'Category:English male dramatists and playwrights': 2,
#  'Category:20th-century essayists': 2,
#  'Category:20th-century English male writers': 2,
#  'Category:19th-century English novelists': 2,
#  'Category:Vector physical quantities': 2,
#  'Category:Recipients of the Copley Medal': 2,
#  'Category:People educated at Eton College': 2,
#  'Category:Alumni of University College London': 2,
#  'Category:Academics of University College London': 2,
#  'Category:Philosophers of technology': 2,
#  'Category:Philosophers of art': 2,
#  'Category:Ontologists': 2,
#  'Category:Members of the United States National Academy of Sciences': 2,
#  "Category:Members of the Men's League": 2,
#  'Category:Epistemologists': 2,
#  'Category:Columbia University faculty': 2,
#  'Category:American political philosophers': 2,
#  'Category:American logicians': 2,
#  'Category:19th-century American philosophers': 2,
#  'Category:Screenwriters from New York (state)': 2,
#  'Category:Film producers from New York (state)': 2,
#  'Category:American television directors': 2,
#  'Category:4th-century translators': 2,
#  'Category:4th-century Christian theologians': 2,
#  'Category:January': 2,
#  'Category:American computer scientists': 2,
#  'Category:21st-century American women': 2,
#  'Category:1952 births': 2,
#  'Category:Neoclassical writers': 2,
#  'Category:English satirists': 2,
#  'Category:English male short story writers': 2,
#  'Category:Doctors of Divinity': 2,
#  'Category:Writers about religion and science': 2,
#  'Category:Fluid dynamicists': 2,
#  'Category:English Anglicans': 2,
#  'Category:Critics of atheism': 2,
#  'Category:Burials at Westminster Abbey': 2,
#  'Category:17th-century English writers': 2,
#  'Category:17th-century English male writers': 2,
#  'Category:American brands': 2,
#  'Category:Territories of the Republic of Venice': 2,
#  'Category:Fellows of the Royal Society of Edinburgh': 2,
#  'Category:Internet memes': 2,
#  'Category:Windows': 2,
#  'Category:Dielectrics': 2,
#  'Category:Metropolitan areas of China': 2,
#  'Category:Primetime Emmy Award winners': 2,
#  'Category:Novelists from New Jersey': 2,
#  'Category:American television writers': 2,
#  'Category:American people of Jewish descent': 2,
#  'Category:American former Christians': 2,
#  'Category:American fantasy writers': 2,
#  'Category:21st-century American short story writers': 2,
#  'Category:Nobel laureates in Physiology or Medicine': 2,
#  'Category:Johns Hopkins University alumni': 2,
#  'Category:United States Army generals': 2,
#  'Category:American surveyors': 2,
#  'Category:United States National Medal of Arts recipients': 2,
#  'Category:Screenwriters from California': 2,
#  'Category:Science Fiction Hall of Fame inductees': 2,
#  'Category:People from Marin County, California': 2,
#  'Category:Nebula Award winners': 2,
#  'Category:Kennedy Center honorees': 2,
#  'Category:Film directors from California': 2,
#  'Category:American philanthropists': 2,
#  'Category:American entertainment industry businesspeople': 2,
#  'Category:Traditional stories': 2,
#  'Category:Lesbian-related films': 2,
#  'Category:1998 films': 2,
#  'Category:Populated places established in the 1st century BC': 2,
#  'Category:Cities and towns in Tuscany': 2,
#  'Category:February': 2,
#  'Category:Telecommunications by country': 2,
#  'Category:Japanese emperors': 2,
#  'Category:English male non-fiction writers': 2,
#  'Category:English essayists': 2,
#  'Category:British male essayists': 2,
#  'Category:Alumni of Magdalen College, Oxford': 2,
#  'Category:18th-century English male writers': 2,
#  'Category:English women novelists': 2,
#  'Category:Legendary Emperors of Japan': 2,
#  'Category:Narratology': 2,
#  'Category:Literary genres': 2,
#  'Category:Programming languages with an ISO standard': 2,
#  'Category:American inventions': 2,
#  'Category:Yale University alumni': 2,
#  'Category:Endocrine system': 2,
#  'Category:Works about history': 2,
#  'Category:HTML': 2,
#  'Category:National Football League teams': 2,
#  'Category:Recipients of the Order of the Red Banner of Labour': 2,
#  'Category:Recipients of the Order of Lenin': 2,
#  'Category:Members of the Serbian Academy of Sciences and Arts': 2,
#  'Category:Male opera composers': 2,
#  'Category:Heroes of Socialist Labour': 2,
#  'Category:Grammatical cases': 2,
#  'Category:Republics': 2,
#  'Category:Greater Antilles': 2,
#  'Category:Countries in North America': 2,
#  'Category:Western (genre) film directors': 2,
#  'Category:Artists from Louisville, Kentucky': 2,
#  'Category:American film producers': 2,
#  'Category:Chemistry-related lists': 2,
#  'Category:Populated places established in 1820': 2,
#  'Category:American Unitarian Universalists': 2,
#  'Category:1906 births': 2,
#  'Category:Constellations': 2,
#  'Category:Toxicology': 2,
#  'Category:Procedural programming languages': 2,
#  'Category:Functional languages': 2,
#  'Category:Dynamically typed programming languages': 2,
#  'Category:Cross-platform free software': 2,
#  'Category:Formal languages': 2,
#  'Category:Disambiguation pages with given-name-holder lists': 2,
#  'Category:Synthetic elements': 2,
#  'Category:Ferromagnetic materials': 2,
#  'Category:Actinides': 2,
#  'Category:Deaths from peritonitis': 2,
#  'Category:Object-oriented programming languages': 2,
#  'Category:American rock guitarists': 2,
#  'Category:American male singer-songwriters': 2,
#  'Category:20th-century American singer-songwriters': 2,
#  'Category:Tributaries of the Rio Negro (Amazon)': 2,
#  'Category:Victor Records artists': 2,
#  'Category:Traditional pop music singers': 2,
#  'Category:Reprise Records artists': 2,
#  'Category:RCA Victor artists': 2,
#  'Category:Brunswick Records artists': 2,
#  'Category:20th-century Roman Catholics': 2,
#  'Category:20th-century American male singers': 2,
#  'Category:1903 births': 2,
#  'Category:Recurring sporting events established in 1981': 2,
#  'Category:Wired (magazine) people': 2,
#  'Category:Honorary Knights Commander of the Order of the British Empire': 2,
#  'Category:Businesspeople in software': 2,
#  'Category:American technology company founders': 2,
#  'Category:American technology chief executives': 2,
#  'Category:American people of Scotch-Irish descent': 2,
#  'Category:American computer programmers': 2,
#  'Category:American billionaires': 2,
#  'Category:Historically recognized angiosperm orders': 2,
#  'Category:Japanese inventions': 2,
#  'Category:American women novelists': 2,
#  'Category:American cannabis activists': 2,
#  'Category:Prime Ministers of Israel': 2,
#  'Category:Ministers of Health of Israel': 2,
#  'Category:Ministers of Foreign Affairs of Israel': 2,
#  'Category:Members of the 16th Knesset (2003–2006)': 2,
#  'Category:Members of the 15th Knesset (1999–2003)': 2,
#  'Category:Members of the 14th Knesset (1996–1999)': 2,
#  'Category:Members of the 13th Knesset (1992–1996)': 2,
#  'Category:Members of the 12th Knesset (1988–1992)': 2,
#  'Category:Likud politicians': 2,
#  'Category:Likud leaders': 2,
#  'Category:Leaders of political parties in Israel': 2,
#  'Category:Jewish military personnel': 2,
#  'Category:Israeli people of the Yom Kippur War': 2,
#  'Category:Israeli people of Belarusian-Jewish descent': 2,
#  'Category:Israeli Ashkenazi Jews': 2,
#  'Category:Hebrew University of Jerusalem alumni': 2,
#  'Category:21st-century prime ministers of Israel': 2,
#  'Category:World Health Organization essential medicines': 2,
#  'Category:Phenols': 2,
#  'Category:Recipients of American presidential pardons': 2,
#  'Category:Neo-Confederates': 2,
#  'Category:American slave owners': 2,
#  'Category:American militia officers': 2,
#  'Category:American military personnel of the Mexican–American War': 2,
#  'Category:1891 deaths': 2,
#  'Category:Singer-songwriters from New York (state)': 2,
#  'Category:Righteous Babe Records artists': 2,
#  'Category:American gun control activists': 2,
#  'Category:American folk singers': 2,
#  'Category:American buskers': 2,
#  'Category:20th-century atheists': 2,
#  'Category:Aeronautics': 2,
#  'Category:Members of the Royal Swedish Academy of Sciences': 2,
#  'Category:21st-century American mathematicians': 2,
#  'Category:1917 births': 2,
#  'Category:French Roman Catholics': 2,
#  'Category:Corinthian colonies': 2,
#  'Category:Eastern Orthodox monarchs': 2,
#  'Category:Knights of the Golden Fleece of Spain': 2,
#  'Category:19th-century deaths from tuberculosis': 2,
#  'Category:Sons of kings': 2,
#  'Category:Special effects people': 2,
#  'Category:Singer-songwriters from California': 2,
#  'Category:American male rappers': 2,
#  'Category:African-American male rappers': 2,
#  'Category:21st-century American rappers': 2,
#  'Category:20th-century American rappers': 2,
#  'Category:April': 2,
#  'Category:Angle': 2,
#  'Category:Writers about the Soviet Union': 2,
#  'Category:Modernist writers': 2,
#  'Category:French male essayists': 2,
#  'Category:French anti-communists': 2,
#  'Category:Writers from Hampstead': 2,
#  'Category:English male poets': 2,
#  "Category:English children's writers": 2,
#  'Category:English autobiographers': 2,
#  'Category:20th-century British dramatists and playwrights': 2,
#  'Category:History of the Mediterranean': 2,
#  'Category:Alkali metals': 2,
#  'Category:Language families': 2,
#  'Category:Left-wing politics': 2,
#  'Category:Anarchism': 2,
#  'Category:Unix text editors': 1,
#  'Category:Emacs': 1,
#  'Category:Computer programming tool stubs': 1,
#  'Category:1981 software': 1,
#  'Category:World War II submarines of Germany': 1,
#  'Category:U-boats commissioned in 1941': 1,
#  'Category:Submarines of the Spanish Navy': 1,
#  'Category:Submarines of Spain': 1,
#  'Category:Spain in World War II': 1,
#  'Category:Ships built in Hamburg': 1,
#  'Category:Maritime incidents in Spain': 1,
#  'Category:Maritime incidents in May 1942': 1,
#  'Category:German Type VIIC submarines': 1,
#  'Category:1941 ships': 1,
#  'Category:NeXT': 1,
#  'Category:Data management': 1,
#  'Category:Apple Inc. software': 1,
#  'Category:Solutions': 1,
#  'Category:Physical properties': 1,
#  'Category:Standard Oil': 1,
#  'Category:Retail companies established in 2017': 1,
#  'Category:Retail companies established in 1889': 1,
#  'Category:Retail companies disestablished in 2004': 1,
#  'Category:Oil pipeline companies': 1,
#  'Category:Non-renewable resource companies established in 2017': 1,
#  'Category:Non-renewable resource companies established in 1889': 1,
#  'Category:Non-renewable resource companies disestablished in 2004': 1,
#  'Category:Natural gas companies of the United States': 1,
#  'Category:Energy companies established in 2017': 1,
#  'Category:Energy companies established in 1889': 1,
#  'Category:Defunct oil companies of the United States': 1,
#  'Category:Companies based in Cook County, Illinois': 1,
#  'Category:Companies based in Chicago': 1,
#  'Category:BP subsidiaries': 1,
#  'Category:Amoco': 1,
#  'Category:American companies established in 2017': 1,
#  'Category:American companies established in 1889': 1,
#  'Category:2017 establishments in Illinois': 1,
#  'Category:2004 disestablishments in Illinois': 1,
#  'Category:1889 establishments in Indiana': 1,
#  'Category:Thioethers': 1,
#  'Category:Sulfur amino acids': 1,
#  'Category:Proteinogenic amino acids': 1,
#  'Category:Glucogenic amino acids': 1,
#  'Category:Essential amino acids': 1,
#  'Category:Alpha-Amino acids': 1,
#  'Category:488 BC': 1,
#  'Category:32 BC': 1,
#  'Category:Sports leagues established in 1999': 1,
#  'Category:Sports leagues disestablished in 2009': 1,
#  'Category:Defunct indoor American football leagues in the United States': 1,
#  'Category:AF2': 1,
#  'Category:2009 disestablishments in the United States': 1,
#  'Category:Medical lists': 1,
#  'Category:Genetics-related lists': 1,
#  'Category:Genetic diseases and disorders': 1,
#  'Category:Disability-related lists': 1,
#  'Category:Health law': 1,
#  'Category:Young adult science fiction novels': 1,
#  'Category:Works originally published in Analog Science Fiction and Fact': 1,
#  'Category:Works based on short fiction': 1,
#  'Category:Works about child soldiers': 1,
#  'Category:Tor Books books': 1,
#  'Category:Novels set in the 22nd century': 1,
#  'Category:Nebula Award for Best Novel-winning works': 1,
#  'Category:Military science fiction novels': 1,
#  'Category:Hugo Award for Best Novel-winning works': 1,
#  'Category:Fictional video games': 1,
#  'Category:Fiction books about genocide': 1,
#  'Category:Fiction about space warfare': 1,
#  "Category:Ender's Game series books": 1,
#  'Category:American young adult novels': 1,
#  'Category:433 Eros': 1,
#  'Category:1985 science fiction novels': 1,
#  'Category:1985 American novels': 1,
#  'Category:Regius Professors of Civil Law (University of Oxford)': 1,
#  'Category:Principals of St Alban Hall, Oxford': 1,
#  'Category:People educated at Winchester College': 1,
#  "Category:Members of Doctors' Commons": 1,
#  'Category:English MPs 1621–1622': 1,
#  'Category:Alumni of New College, Oxford': 1,
#  'Category:17th-century English judges': 1,
#  'Category:1661 deaths': 1,
#  'Category:1590s births': 1,
#  'Category:Scottish inventors': 1,
#  'Category:People from Angus, Scotland': 1,
#  'Category:People associated with Dundee': 1,
#  'Category:Alumni of the University of St Andrews': 1,
#  'Category:Technology timelines': 1,
#  'Category:Spaceflight timelines': 1,
#  'Category:Science timelines': 1,
#  'Category:Military timelines': 1,
#  'Category:Aviation timelines': 1,
#  'Category:Neuroendocrinology': 1,
#  'Category:Limbic system': 1,
#  'Category:Hypothalamus': 1,
#  'Category:Human female endocrine system': 1,
#  'Category:Straits': 1,
#  'Category:Coastal and oceanic landforms': 1,
#  'Category:Bodies of water': 1,
#  'Category:Think tanks based in the State of Palestine': 1,
#  'Category:Palestinian nationalism': 1,
#  'Category:Organizations based in Jerusalem': 1,
#  'Category:Non-profit organizations based in the State of Palestine': 1,
#  'Category:Non-governmental organizations involved in the Israeli–Palestinian conflict': 1,
#  'Category:Educational institutions established in 1987': 1,
#  'Category:1987 establishments in the Palestinian territories': 1,
#  'Category:Populated places established in the 9th century': 1,
#  'Category:Municipalities in the Province of Badajoz': 1,
#  'Category:Badajoz': 1,
#  'Category:9th-century establishments in Spain': 1,
#  'Category:875 establishments': 1,
#  'Category:Aircraft wing design': 1,
#  'Category:Aircraft aerodynamics': 1,
#  'Category:Italian slasher films': 1,
#  'Category:Italian serial killer films': 1,
#  'Category:Italian mystery thriller films': 1,
#  'Category:Italian horror thriller films': 1,
#  'Category:Italian crime thriller films': 1,
#  'Category:Giallo films': 1,
#  'Category:Films shot in Barcelona': 1,
#  'Category:Films scored by Bruno Nicolai': 1,
#  'Category:Films directed by Umberto Lenzi': 1,
#  'Category:1970s slasher films': 1,
#  'Category:1970s serial killer films': 1,
#  'Category:1970s mystery thriller films': 1,
#  'Category:1970s horror thriller films': 1,
#  'Category:1970s horror film stubs': 1,
#  'Category:1970s exploitation films': 1,
#  'Category:1970s crime thriller films': 1,
#  'Category:1970s Italian film stubs': 1,
#  'Category:Michigan geography-related lists': 1,
#  'Category:Michigan counties': 1,
#  'Category:Lists of counties of the United States by state': 1,
#  'Category:Peerages in the United Kingdom': 1,
#  'Category:World Heritage Sites in Lebanon': 1,
#  'Category:Tourist attractions in Lebanon': 1,
#  'Category:Tourism in Lebanon': 1,
#  'Category:Sunni Muslim communities in Lebanon': 1,
#  'Category:Roman sites in Lebanon': 1,
#  'Category:Pre-Pottery Neolithic B': 1,
#  'Category:Populated places in Baalbek District': 1,
#  'Category:Populated places established in the 7th millennium BC': 1,
#  'Category:Phoenician sites in Lebanon': 1,
#  'Category:Phoenician cities': 1,
#  'Category:Great Rift Valley': 1,
#  'Category:Coloniae (Roman)': 1,
#  'Category:Archaeological sites in Lebanon': 1,
#  'Category:7th-millennium BC establishments': 1,
#  'Category:77 BC': 1,
#  'Category:Television networks in the United Kingdom': 1,
#  'Category:ITV (TV network)': 1,
#  'Category:State holidays in the United States': 1,
#  'Category:Public holidays in the United Kingdom': 1,
#  'Category:Public holidays in the Republic of Ireland': 1,
#  'Category:Public holidays in the Philippines': 1,
#  'Category:Public holidays in the Dominican Republic': 1,
#  'Category:Public holidays in the Czech Republic': 1,
#  'Category:Public holidays in the Bahamas': 1,
#  'Category:Public holidays in Zimbabwe': 1,
#  'Category:Public holidays in Zambia': 1,
#  'Category:Public holidays in Venezuela': 1,
#  'Category:Public holidays in Uganda': 1,
#  'Category:Public holidays in Trinidad and Tobago': 1,
#  'Category:Public holidays in Tanzania': 1,
#  'Category:Public holidays in Switzerland': 1,
#  'Category:Public holidays in Sweden': 1,
#  'Category:Public holidays in Sri Lanka': 1,
#  'Category:Public holidays in Spain': 1,
#  'Category:Public holidays in South Africa': 1,
#  'Category:Public holidays in Slovakia': 1,
#  'Category:Public holidays in Singapore': 1,
#  'Category:Public holidays in Rwanda': 1,
#  'Category:Public holidays in Portugal': 1,
#  'Category:Public holidays in Peru': 1,
#  'Category:Public holidays in Paraguay': 1,
#  'Category:Public holidays in Norway': 1,
#  'Category:Public holidays in Nigeria': 1,
#  'Category:Public holidays in New Zealand': 1,
#  'Category:Public holidays in Mexico': 1,
#  'Category:Public holidays in Malta': 1,
#  'Category:Public holidays in Malaysia': 1,
#  'Category:Public holidays in Luxembourg': 1,
#  'Category:Public holidays in Liechtenstein': 1,
#  'Category:Public holidays in Latvia': 1,
#  'Category:Public holidays in Kenya': 1,
#  'Category:Public holidays in Jamaica': 1,
#  'Category:Public holidays in Indonesia': 1,
#  'Category:Public holidays in India': 1,
#  'Category:Public holidays in Iceland': 1,
#  'Category:Public holidays in Hungary': 1,
#  'Category:Public holidays in Honduras': 1,
#  'Category:Public holidays in Grenada': 1,
#  'Category:Public holidays in Greece': 1,
#  'Category:Public holidays in Ghana': 1,
#  'Category:Public holidays in Germany': 1,
#  'Category:Public holidays in France': 1,
#  'Category:Public holidays in Finland': 1,
#  'Category:Public holidays in Fiji': 1,
#  'Category:Public holidays in Estonia': 1,
#  'Category:Public holidays in El Salvador': 1,
#  'Category:Public holidays in Denmark': 1,
#  'Category:Public holidays in Costa Rica': 1,
#  'Category:Public holidays in Colombia': 1,
#  'Category:Public holidays in Chile': 1,
#  'Category:Public holidays in Canada': 1,
#  'Category:Public holidays in Brazil': 1,
#  'Category:Public holidays in Botswana': 1,
#  'Category:Public holidays in Bolivia': 1,
#  'Category:Public holidays in Barbados': 1,
#  'Category:Public holidays in Australia': 1,
#  'Category:Public holidays in Argentina': 1,
#  'Category:Public holidays in Angola': 1,
#  'Category:March observances': 1,
#  'Category:Holy Week': 1,
#  'Category:Greek traditions': 1,
#  'Category:Friday observances': 1,
#  'Category:Divine Mercy (Catholic devotion)': 1,
#  'Category:Crucifixion of Jesus': 1,
#  'Category:April observances': 1,
#  'Category:Tennessee counties': 1,
#  'Category:Populated places established in 1796': 1,
#  'Category:Montgomery County, Tennessee': 1,
#  'Category:Middle Tennessee': 1,
#  'Category:Clarksville metropolitan area': 1,
#  'Category:1796 establishments in Tennessee': 1,
#  "Category:Second Barons' War": 1,
#  'Category:Registered historic battlefields in England': 1,
#  'Category:Military history of Worcestershire': 1,
#  'Category:Evesham': 1,
#  'Category:Edward I of England': 1,
#  'Category:Conflicts in 1265': 1,
#  "Category:Battles of the Barons' Wars": 1,
#  'Category:1265 in England': 1,
#  'Category:Percussionists': 1,
#  'Category:Lists of musicians by instrument': 1,
#  'Category:Populated places established in 1807': 1,
#  'Category:Kentucky counties': 1,
#  'Category:Counties of Appalachia': 1,
#  'Category:Clay County, Kentucky': 1,
#  'Category:1807 establishments in Kentucky': 1,
#  'Category:Wildfires in Colorado': 1,
#  'Category:Natural disasters in Colorado': 1,
#  'Category:Mass murder in 2002': 1,
#  'Category:Arson in Colorado': 1,
#  'Category:2002 wildfires in the United States': 1,
#  'Category:2002 in Colorado': 1,
#  'Category:Ramjet engines': 1,
#  'Category:Projects of the United States Air Force': 1,
#  'Category:Nuclear research reactors': 1,
#  'Category:Nuclear propulsion': 1,
#  'Category:Nevada Test Site': 1,
#  'Category:Military nuclear reactors': 1,
#  'Category:Engineering projects': 1,
#  'Category:Abandoned military projects of the United States': 1,
#  'Category:Foreign relations of Norway': 1,
#  'Category:Tropical agriculture': 1,
#  'Category:Palm oil': 1,
#  'Category:Environmental controversies': 1,
#  'Category:Crops': 1,
#  'Category:Warner Bros. Games': 1,
#  'Category:Video game companies of the United States': 1,
#  'Category:Video game companies established in 1994': 1,
#  'Category:Needham, Massachusetts': 1,
#  'Category:Companies based in Norfolk County, Massachusetts': 1,
#  'Category:American companies established in 1994': 1,
#  'Category:2010 mergers and acquisitions': 1,
#  'Category:1994 establishments in Massachusetts': 1,
#  'Category:Port cities in the Caribbean': 1,
#  'Category:Port-au-Prince': 1,
#  'Category:Populated places in Ouest (department)': 1,
#  'Category:Populated places established in 1749': 1,
#  'Category:Populated coastal places in Haiti': 1,
#  'Category:Gulf of Gonâve': 1,
#  'Category:Communes of Haiti': 1,
#  'Category:Capitals in the Caribbean': 1,
#  'Category:Capitals in North America': 1,
#  'Category:1749 establishments in the French colonial empire': 1,
#  'Category:Populated places established in 1853': 1,
#  'Category:Iowa counties': 1,
#  'Category:Adams County, Iowa': 1,
#  'Category:1853 establishments in Iowa': 1,
#  'Category:TGV': 1,
#  'Category:SNCF brands': 1,
#  'Category:SNCF': 1,
#  'Category:Railway services introduced in 1981': 1,
#  'Category:Railteam': 1,
#  'Category:Rail transport in Europe': 1,
#  'Category:Rail transport brands': 1,
#  'Category:Land speed records': 1,
#  'Category:High-speed trains': 1,
#  'Category:High-speed rail in France': 1,
#  'Category:Eurostar': 1,
#  'Category:1981 establishments in France': 1,
#  'Category:Provinces of the Netherlands': 1,
#  'Category:Overijssel': 1,
#  'Category:History of the Marshall Islands': 1,
#  'Category:Birds of prey': 1,
#  'Category:Bird common names': 1,
#  'Category:Writers from Saskatchewan': 1,
#  'Category:University of Toronto alumni': 1,
#  'Category:University of Toronto Faculty of Law alumni': 1,
#  'Category:University of Manitoba alumni': 1,
#  'Category:People from Weyburn': 1,
#  'Category:Members of the Order of Canada': 1,
#  'Category:Lawyers in Ontario': 1,
#  'Category:Canadian male novelists': 1,
#  'Category:Canadian fantasy writers': 1,
#  'Category:Aurora Award-winning writers': 1,
#  'Category:21st-century Canadian novelists': 1,
#  'Category:20th-century Canadian novelists': 1,
#  'Category:1954 births': 1,
#  'Category:South-East District (Botswana)': 1,
#  'Category:Populated places established in 1964': 1,
#  'Category:Planned capitals': 1,
#  'Category:New towns started in the 1960s': 1,
#  'Category:Gaborone': 1,
#  'Category:District capitals in Botswana': 1,
#  'Category:Cities in Botswana': 1,
#  'Category:Capitals in Africa': 1,
#  'Category:1964 establishments in Africa': 1,
#  'Category:NGC objects': 1,
#  'Category:IC objects': 1,
#  'Category:Astronomical catalogues': 1,
#  'Category:1888 in science': 1,
#  'Category:1888 documents': 1,
#  'Category:Right-wing politics': 1,
#  'Category:Political spectrum': 1,
#  'Category:Writers on Zionism': 1,
#  'Category:Right-wing populists': 1,
#  'Category:Right-wing populism in Israel': 1,
#  'Category:Politicians from Tel Aviv': 1,
#  'Category:Politicians from Jerusalem': 1,
#  'Category:Permanent Representatives of Israel to the United Nations': 1,
#  'Category:People of the Military Intelligence Directorate (Israel)': 1,
#  'Category:People from Cheltenham, Pennsylvania': 1,
#  'Category:Netanyahu family': 1,
#  'Category:Ministers of finance of Israel': 1,
#  'Category:Ministers of Justice of Israel': 1,
#  'Category:Ministers of Communications of Israel': 1,
#  'Category:Members of the 25th Knesset (2022–)': 1,
#  'Category:Members of the 24th Knesset (2021–2022)': 1,
#  'Category:Members of the 23rd Knesset (2020–2021)': 1,
#  'Category:Members of the 22nd Knesset (2019–2020)': 1,
#  'Category:Members of the 21st Knesset (2019)': 1,
#  'Category:Members of the 20th Knesset (2015–2019)': 1,
#  'Category:Members of the 19th Knesset (2013–2015)': 1,
#  'Category:Members of the 18th Knesset (2009–2013)': 1,
#  'Category:Members of the 17th Knesset (2006–2009)': 1,
#  'Category:MIT Sloan School of Management alumni': 1,
#  'Category:MIT School of Architecture and Planning alumni': 1,
#  'Category:Leaders of the Opposition (Israel)': 1,
#  'Category:Jewish non-fiction writers': 1,
#  'Category:Jewish Israeli writers': 1,
#  'Category:Jewish Israeli politicians': 1,
#  'Category:Israeli soldiers': 1,
#  'Category:Israeli secular Jews': 1,
#  'Category:Israeli political writers': 1,
#  'Category:Israeli people of Polish-Jewish descent': 1,
#  'Category:Israeli people of Lithuanian-Jewish descent': 1,
#  'Category:Israeli nationalists': 1,
#  'Category:Israeli management consultants': 1,
#  'Category:Israeli male non-fiction writers': 1,
#  'Category:Israeli expatriates in the United States': 1,
#  'Category:Israeli chief executives': 1,
#  'Category:Deputy ministers of Israel': 1,
#  'Category:Chief marketing officers': 1,
#  'Category:Boston Consulting Group people': 1,
#  'Category:Benjamin Netanyahu': 1,
#  'Category:21st-century diplomats': 1,
#  'Category:20th-century prime ministers of Israel': 1,
#  'Category:20th-century non-fiction writers': 1,
#  'Category:20th-century diplomats': 1,
#  'Category:20th-century Israeli male writers': 1,
#  'Category:Opera composers': 1,
#  'Category:Opera-related lists': 1,
#  'Category:Lists of composers': 1,
#  'Category:Jack Dann and Gardner Dozois Ace anthologies': 1,
#  'Category:Fiction about nanotechnology': 1,
#  'Category:Ace Books books': 1,
#  'Category:1998 anthologies': 1,
#  'Category:Suspected fetotoxicants': 1,
#  'Category:Reproductive toxicants': 1,
#  'Category:Monomers': 1,
#  'Category:IARC Group 2A carcinogens': 1,
#  'Category:Carboxamides': 1,
#  'Category:Acrylamides': 1,
#  'Category:Rochester metropolitan area, New York': 1,
#  'Category:Populated places established in 1824': 1,
#  'Category:Orleans County, New York': 1,
#  'Category:1824 establishments in New York (state)': 1,
#  'Category:Takeover defense': 1,
#  'Category:Shareholders': 1,
#  'Category:Metaphors referring to war and violence': 1,
#  'Category:Mergers and acquisitions': 1,
#  "Category:Wikipedia articles incorporating text from the 20th edition of Gray's Anatomy (1918)": 1,
#  'Category:Tongue': 1,
#  'Category:Speech organs': 1,
#  'Category:Sensory organs': 1,
#  'Category:Human mouth anatomy': 1,
#  'Category:Gustatory system': 1,
#  'Category:Digestive system': 1,
#  "Category:Men's health": 1,
#  'Category:Inflammatory prostate disorders': 1,
#  'Category:Inflammations': 1,
#  'Category:Logic': 1,
#  'Category:History of logic': 1,
#  'Category:Classical logic': 1,
#  'Category:United States federal securities legislation': 1,
#  'Category:United States federal legislation stubs': 1,
#  'Category:1934 in international relations': 1,
#  'Category:1934 in economic history': 1,
#  'Category:1934 in American law': 1,
#  'Category:United States railroad regulation': 1,
#  'Category:United States federal transportation legislation': 1,
#  'Category:Progressive Era in the United States': 1,
#  'Category:1910 in rail transport': 1,
#  'Category:1910 in American law': 1,
#  'Category:Hospitals': 1,
#  'Category:Hospital staff': 1,
#  'Category:Regions of Europe': 1,
#  'Category:Geography of the European Union': 1,
#  'Category:United States federal trade legislation': 1,
#  'Category:Andrew Jackson': 1,
#  'Category:22nd United States Congress': 1,
#  'Category:1833 in the United States': 1,
#  'Category:1833 in American law': 1,
#  'Category:10th century BC': 1,
#  'Category:Simon & Schuster books': 1,
#  'Category:Satirical novels': 1,
#  'Category:Novels set during World War II': 1,
#  'Category:Novels by Joseph Heller': 1,
#  'Category:Nonlinear narrative novels': 1,
#  'Category:Military humor': 1,
#  ...}

# %%
to_delete = []
for k, v in sorted_hashmap.items():
    if ("article" in k.lower()) or\
    ("wiki" in k.lower()) or\
    ("sources" in k.lower()) or\
    ("cs" in k.lower()) or\
    ("webarchive" in k.lower()) or\
    ("pages" in k.lower()) or\
    ("use dmy dates" in k.lower()) or\
    ("use mdy dates" in k.lower()) or\
    ("all accuracy disputes" in k.lower()) or\
    ("american" in k.lower()) or\
    ("births" in k.lower()):
        to_delete.append(k)

for k in to_delete:
    del sorted_hashmap[k]

# %%
sorted_hashmap
# Out:
# {'Category:Living people': 35,
#  'Category:Days of the year': 16,
#  'Category:Fellows of the Royal Society': 7,
#  'Category:Columbia Records artists': 6,
#  'Category:Philosophers of science': 5,
#  'Category:Chemical elements': 5,
#  'Category:Decca Records artists': 5,
#  'Category:Hugo Award-winning writers': 5,
#  'Category:Grammy Award winners': 5,
#  'Category:United States National Film Registry films': 4,
#  'Category:Telecommunications stubs': 4,
#  'Category:Films whose editor won the Best Film Editing Academy Award': 4,
#  'Category:Centuries': 4,
#  'Category:Leap years in the Gregorian calendar': 4,
#  'Category:Tony Award winners': 4,
#  'Category:1990s English-language films': 4,
#  'Category:20th-century short story writers': 4,
#  'Category:Knights Bachelor': 4,
#  'Category:Presidential Medal of Freedom recipients': 4,
#  'Category:Harvard College alumni': 4,
#  'Category:Latin words and phrases': 4,
#  'Category:Alumni of Trinity College, Cambridge': 4,
#  'Category:New York (state) counties': 3,
#  'Category:Political terminology': 3,
#  'Category:Films whose art director won the Best Art Direction Academy Award': 3,
#  'Category:Best Picture Academy Award winners': 3,
#  'Category:Films whose cinematographer won the Best Cinematography Academy Award': 3,
#  'Category:General topology': 3,
#  'Category:Gases': 3,
#  'Category:Chemical properties': 3,
#  'Category:Laurence Olivier Award winners': 3,
#  'Category:Drama Desk Award winners': 3,
#  'Category:Trigonal minerals': 3,
#  'Category:Films shot in California': 3,
#  'Category:Films set in Egypt': 3,
#  'Category:Medicinal plants': 3,
#  'Category:Edgar Award winners': 3,
#  'Category:Heads of government who were later imprisoned': 3,
#  'Category:Recipients of the Legion of Honour': 3,
#  'Category:Popes': 3,
#  'Category:Italian popes': 3,
#  'Category:Aluminium minerals': 3,
#  'Category:Hipparcos objects': 3,
#  'Category:Henry Draper Catalogue objects': 3,
#  'Category:Flamsteed objects': 3,
#  'Category:Durchmusterung objects': 3,
#  'Category:Bayer objects': 3,
#  'Category:Writers from Chicago': 3,
#  'Category:United States Army soldiers': 3,
#  'Category:Foreign Members of the Royal Society': 3,
#  'Category:British Nobel laureates': 3,
#  'Category:Foreign associates of the National Academy of Sciences': 3,
#  'Category:2004 deaths': 3,
#  'Category:University of Chicago faculty': 3,
#  'Category:Philosophers of mind': 3,
#  'Category:Video game development companies': 3,
#  'Category:Pseudoscience': 3,
#  'Category:World Fantasy Award-winning writers': 3,
#  'Category:Weird fiction writers': 3,
#  'Category:Congressional Gold Medal recipients': 3,
#  'Category:Capitals of former nations': 3,
#  'Category:Founding monarchs': 3,
#  'Category:Telegraphy': 3,
#  'Category:Inkpot Award winners': 3,
#  'Category:Commandeurs of the Ordre des Arts et des Lettres': 3,
#  'Category:Spanish-speaking countries and territories': 3,
#  'Category:Member states of the United Nations': 3,
#  'Category:Former Spanish colonies': 3,
#  'Category:Christian terminology': 3,
#  'Category:Cross-platform software': 3,
#  'Category:Subprefectures in France': 3,
#  'Category:Grammy Lifetime Achievement Award winners': 3,
#  'Category:Art movements': 3,
#  'Category:E-number additives': 3,
#  'Category:Deaths from kidney failure': 3,
#  'Category:2014 deaths': 3,
#  'Category:Activists from New York (state)': 3,
#  'Category:Constellations listed by Ptolemy': 3,
#  'Category:Grand Crosses of the Order of Saint Stephen of Hungary': 3,
#  'Category:Nobel laureates in Literature': 3,
#  'Category:August': 3,
#  'Category:People educated at Westminster School, London': 3,
#  'Category:English male novelists': 3,
#  'Category:20th-century English novelists': 3,
#  'Category:Lists of diseases': 2,
#  'Category:Adirondacks': 2,
#  'Category:Jewish Canadian writers': 2,
#  'Category:Fiction about near-Earth asteroids': 2,
#  'Category:Paramount Pictures films': 2,
#  'Category:Films shot in Hertfordshire': 2,
#  'Category:Films about treasure hunting': 2,
#  'Category:1999 establishments in the United States': 2,
#  'Category:MIRV capable missiles': 2,
#  'Category:Chaos theorists': 2,
#  'Category:Recipients of the Order of the White Eagle (Poland)': 2,
#  'Category:Logic families': 2,
#  'Category:Recipients of the Navy Distinguished Service Medal': 2,
#  'Category:Fortified settlements': 2,
#  'Category:Brit Award winners': 2,
#  'Category:Films shot in Europe': 2,
#  'Category:Films set in Greece': 2,
#  'Category:Films set in New York City': 2,
#  'Category:1970s English-language films': 2,
#  'Category:Urban legends': 2,
#  'Category:2001 deaths': 2,
#  'Category:Films set in Paris': 2,
#  'Category:BC year stubs': 2,
#  'Category:1862 deaths': 2,
#  'Category:Princeton University faculty': 2,
#  'Category:2019 deaths': 2,
#  'Category:Economic history of the United States': 2,
#  'Category:Gulfs of the Atlantic Ocean': 2,
#  'Category:Films whose director won the Best Directing Academy Award': 2,
#  'Category:Films featuring a Best Supporting Actress Academy Award-winning performance': 2,
#  'Category:Best Drama Picture Golden Globe winners': 2,
#  'Category:Linear algebra': 2,
#  'Category:United States communications regulation': 2,
#  'Category:Male musical theatre composers': 2,
#  'Category:Broadway composers and lyricists': 2,
#  'Category:Data transmission': 2,
#  'Category:Multiplexing': 2,
#  'Category:Telephony signals': 2,
#  'Category:Embedded systems': 2,
#  'Category:Documents of the Second Vatican Council': 2,
#  'Category:2nd millennium BC': 2,
#  'Category:Warner Bros. films': 2,
#  'Category:Films whose director won the Best Director Golden Globe': 2,
#  'Category:Films set in Washington, D.C.': 2,
#  'Category:Films scored by John Williams': 2,
#  'Category:Cultural depictions of Lee Harvey Oswald': 2,
#  'Category:Optical quantities': 2,
#  'Category:Independent Spirit Award for Best Female Lead winners': 2,
#  'Category:Harvard University alumni': 2,
#  'Category:Science fiction novels adapted into films': 2,
#  'Category:Ballistic missiles': 2,
#  'Category:French male non-fiction writers': 2,
#  'Category:Academic staff of the University of Paris': 2,
#  'Category:Chemical bonding': 2,
#  'Category:Films about nuclear war and weapons': 2,
#  'Category:Cold War films': 2,
#  'Category:British black-and-white films': 2,
#  'Category:1960s English-language films': 2,
#  'Category:1960s British films': 2,
#  'Category:Writers from New York City': 2,
#  'Category:Monarchs taken prisoner in wartime': 2,
#  'Category:Telecommunications engineering': 2,
#  'Category:Integrated circuits': 2,
#  'Category:16th-century English women': 2,
#  'Category:Countries in Africa': 2,
#  'Category:Deaths from cancer in England': 2,
#  'Category:Voting theorists': 2,
#  'Category:Fictional military personnel in films': 2,
#  'Category:Fictional commanders': 2,
#  'Category:NMDA receptor antagonists': 2,
#  'Category:Hazardous air pollutants': 2,
#  'Category:Soviet Union–United States relations': 2,
#  'Category:Presidency of Dwight D. Eisenhower': 2,
#  'Category:Writers Guild of America Award winners': 2,
#  'Category:Writers who illustrated their own writing': 2,
#  'Category:University of Paris alumni': 2,
#  'Category:Naturalised citizens of the United Kingdom': 2,
#  'Category:Members of the Order of Merit': 2,
#  'Category:Lecturers': 2,
#  'Category:Ivor Novello Award winners': 2,
#  'Category:Institute for Advanced Study visiting scholars': 2,
#  'Category:Superhard materials': 2,
#  'Category:Oxide minerals': 2,
#  'Category:Minerals in space group 167': 2,
#  'Category:Corundum gemstones': 2,
#  'Category:Electronic design': 2,
#  'Category:Super Bowl': 2,
#  'Category:Physiographic provinces': 2,
#  'Category:Works of unknown authorship': 2,
#  'Category:MacArthur Fellows': 2,
#  'Category:Black Lion Records artists': 2,
#  'Category:United Artists films': 2,
#  'Category:Films based on multiple works': 2,
#  'Category:1970s Italian films': 2,
#  'Category:1970s Italian-language films': 2,
#  'Category:Metro-Goldwyn-Mayer films': 2,
#  'Category:Films adapted into television shows': 2,
#  'Category:Films about archaeology': 2,
#  'Category:1990s science fiction action films': 2,
#  'Category:Fictional military strategists': 2,
#  'Category:Writers about activism and social change': 2,
#  'Category:Corresponding Fellows of the British Academy': 2,
#  'Category:States of Germany': 2,
#  'Category:Time Person of the Year': 2,
#  'Category:People stripped of honorary degrees': 2,
#  'Category:New York (state) Republicans': 2,
#  'Category:Princeton University alumni': 2,
#  'Category:Nobel laureates affiliated with Missouri': 2,
#  'Category:Austro-Hungarian military personnel of World War I': 2,
#  'Category:Subshrubs': 2,
#  'Category:Mediterranean cuisine': 2,
#  'Category:Herbs': 2,
#  'Category:Flora of the Mediterranean Basin': 2,
#  'Category:César Honorary Award recipients': 2,
#  'Category:Best Screenplay Golden Globe winners': 2,
#  'Category:Best Original Screenplay Academy Award winners': 2,
#  'Category:Spirituality': 2,
#  'Category:Superscalar microprocessors': 2,
#  'Category:Carnivorans of Europe': 2,
#  'Category:Password authentication': 2,
#  'Category:Leaders who took power by coup': 2,
#  'Category:Philosophy of language literature': 2,
#  'Category:Books by Ludwig Wittgenstein': 2,
#  'Category:Analytic philosophy literature': 2,
#  'Category:Postmodern novels': 2,
#  'Category:Social philosophers': 2,
#  'Category:Postmodern writers': 2,
#  'Category:Political philosophers': 2,
#  'Category:Philosophers of love': 2,
#  'Category:Philosophers of history': 2,
#  'Category:Philosophers of culture': 2,
#  'Category:Philosophers from California': 2,
#  'Category:Counterculture of the 1960s': 2,
#  'Category:Source code': 2,
#  'Category:English people of French descent': 2,
#  'Category:Poetic forms': 2,
#  'Category:Epic Records artists': 2,
#  'Category:Black comedy': 2,
#  'Category:Evolutionary biology': 2,
#  'Category:November': 2,
#  'Category:Transition metals': 2,
#  'Category:Stars with proper names': 2,
#  'Category:Bright Star Catalogue objects': 2,
#  'Category:Oil companies of the United States': 2,
#  'Category:Gas stations in the United States': 2,
#  'Category:Automotive fuel retailers': 2,
#  'Category:Phase transitions': 2,
#  'Category:Materials science': 2,
#  'Category:Medical volunteerism': 2,
#  'Category:Mechanical quantities': 2,
#  'Category:March': 2,
#  'Category:Modernism': 2,
#  'Category:Virgin Records artists': 2,
#  'Category:V2 Records artists': 2,
#  'Category:Fontana Records artists': 2,
#  'Category:Urban districts of Bavaria': 2,
#  'Category:Cities in Bavaria': 2,
#  'Category:Illeists': 2,
#  'Category:Chemical elements with face-centered cubic structure': 2,
#  'Category:1982 deaths': 2,
#  'Category:Austrian male novelists': 2,
#  'Category:Regions of Michigan': 2,
#  'Category:Kings of Dál Riata': 2,
#  'Category:Gaelic monarchs in Scotland': 2,
#  'Category:Citrus': 2,
#  'Category:Extreme programming': 2,
#  'Category:Mechanical engineering': 2,
#  'Category:Nobel laureates in Chemistry': 2,
#  'Category:English Nobel laureates': 2,
#  'Category:Ghost story writers': 2,
#  'Category:English male dramatists and playwrights': 2,
#  'Category:20th-century essayists': 2,
#  'Category:20th-century English male writers': 2,
#  'Category:19th-century English novelists': 2,
#  'Category:Vector physical quantities': 2,
#  'Category:Recipients of the Copley Medal': 2,
#  'Category:People educated at Eton College': 2,
#  'Category:Alumni of University College London': 2,
#  'Category:Philosophers of technology': 2,
#  'Category:Philosophers of art': 2,
#  'Category:Ontologists': 2,
#  'Category:Members of the United States National Academy of Sciences': 2,
#  "Category:Members of the Men's League": 2,
#  'Category:Epistemologists': 2,
#  'Category:Columbia University faculty': 2,
#  'Category:Screenwriters from New York (state)': 2,
#  'Category:Film producers from New York (state)': 2,
#  'Category:4th-century translators': 2,
#  'Category:4th-century Christian theologians': 2,
#  'Category:January': 2,
#  'Category:Neoclassical writers': 2,
#  'Category:English satirists': 2,
#  'Category:English male short story writers': 2,
#  'Category:Doctors of Divinity': 2,
#  'Category:Writers about religion and science': 2,
#  'Category:Fluid dynamicists': 2,
#  'Category:English Anglicans': 2,
#  'Category:Burials at Westminster Abbey': 2,
#  'Category:17th-century English writers': 2,
#  'Category:17th-century English male writers': 2,
#  'Category:Territories of the Republic of Venice': 2,
#  'Category:Fellows of the Royal Society of Edinburgh': 2,
#  'Category:Internet memes': 2,
#  'Category:Windows': 2,
#  'Category:Metropolitan areas of China': 2,
#  'Category:Primetime Emmy Award winners': 2,
#  'Category:Novelists from New Jersey': 2,
#  'Category:Nobel laureates in Physiology or Medicine': 2,
#  'Category:Johns Hopkins University alumni': 2,
#  'Category:United States Army generals': 2,
#  'Category:United States National Medal of Arts recipients': 2,
#  'Category:Screenwriters from California': 2,
#  'Category:Science Fiction Hall of Fame inductees': 2,
#  'Category:People from Marin County, California': 2,
#  'Category:Nebula Award winners': 2,
#  'Category:Kennedy Center honorees': 2,
#  'Category:Film directors from California': 2,
#  'Category:Traditional stories': 2,
#  'Category:Lesbian-related films': 2,
#  'Category:1998 films': 2,
#  'Category:Populated places established in the 1st century BC': 2,
#  'Category:Cities and towns in Tuscany': 2,
#  'Category:February': 2,
#  'Category:Telecommunications by country': 2,
#  'Category:Japanese emperors': 2,
#  'Category:English male non-fiction writers': 2,
#  'Category:English essayists': 2,
#  'Category:British male essayists': 2,
#  'Category:Alumni of Magdalen College, Oxford': 2,
#  'Category:18th-century English male writers': 2,
#  'Category:English women novelists': 2,
#  'Category:Legendary Emperors of Japan': 2,
#  'Category:Narratology': 2,
#  'Category:Literary genres': 2,
#  'Category:Programming languages with an ISO standard': 2,
#  'Category:Yale University alumni': 2,
#  'Category:Endocrine system': 2,
#  'Category:Works about history': 2,
#  'Category:HTML': 2,
#  'Category:National Football League teams': 2,
#  'Category:Recipients of the Order of the Red Banner of Labour': 2,
#  'Category:Recipients of the Order of Lenin': 2,
#  'Category:Members of the Serbian Academy of Sciences and Arts': 2,
#  'Category:Male opera composers': 2,
#  'Category:Heroes of Socialist Labour': 2,
#  'Category:Grammatical cases': 2,
#  'Category:Greater Antilles': 2,
#  'Category:Countries in North America': 2,
#  'Category:Western (genre) film directors': 2,
#  'Category:Artists from Louisville, Kentucky': 2,
#  'Category:Chemistry-related lists': 2,
#  'Category:Populated places established in 1820': 2,
#  'Category:Constellations': 2,
#  'Category:Toxicology': 2,
#  'Category:Procedural programming languages': 2,
#  'Category:Functional languages': 2,
#  'Category:Dynamically typed programming languages': 2,
#  'Category:Cross-platform free software': 2,
#  'Category:Formal languages': 2,
#  'Category:Synthetic elements': 2,
#  'Category:Ferromagnetic materials': 2,
#  'Category:Actinides': 2,
#  'Category:Deaths from peritonitis': 2,
#  'Category:Object-oriented programming languages': 2,
#  'Category:Tributaries of the Rio Negro (Amazon)': 2,
#  'Category:Victor Records artists': 2,
#  'Category:Traditional pop music singers': 2,
#  'Category:Reprise Records artists': 2,
#  'Category:RCA Victor artists': 2,
#  'Category:Brunswick Records artists': 2,
#  'Category:Recurring sporting events established in 1981': 2,
#  'Category:Wired (magazine) people': 2,
#  'Category:Honorary Knights Commander of the Order of the British Empire': 2,
#  'Category:Businesspeople in software': 2,
#  'Category:Historically recognized angiosperm orders': 2,
#  'Category:Japanese inventions': 2,
#  'Category:Prime Ministers of Israel': 2,
#  'Category:Ministers of Health of Israel': 2,
#  'Category:Ministers of Foreign Affairs of Israel': 2,
#  'Category:Members of the 16th Knesset (2003–2006)': 2,
#  'Category:Members of the 15th Knesset (1999–2003)': 2,
#  'Category:Members of the 14th Knesset (1996–1999)': 2,
#  'Category:Members of the 13th Knesset (1992–1996)': 2,
#  'Category:Members of the 12th Knesset (1988–1992)': 2,
#  'Category:Likud politicians': 2,
#  'Category:Likud leaders': 2,
#  'Category:Leaders of political parties in Israel': 2,
#  'Category:Jewish military personnel': 2,
#  'Category:Israeli people of the Yom Kippur War': 2,
#  'Category:Israeli people of Belarusian-Jewish descent': 2,
#  'Category:Israeli Ashkenazi Jews': 2,
#  'Category:Hebrew University of Jerusalem alumni': 2,
#  'Category:21st-century prime ministers of Israel': 2,
#  'Category:World Health Organization essential medicines': 2,
#  'Category:Phenols': 2,
#  'Category:Neo-Confederates': 2,
#  'Category:1891 deaths': 2,
#  'Category:Singer-songwriters from New York (state)': 2,
#  'Category:Righteous Babe Records artists': 2,
#  'Category:20th-century atheists': 2,
#  'Category:Members of the Royal Swedish Academy of Sciences': 2,
#  'Category:Corinthian colonies': 2,
#  'Category:Eastern Orthodox monarchs': 2,
#  'Category:Knights of the Golden Fleece of Spain': 2,
#  'Category:19th-century deaths from tuberculosis': 2,
#  'Category:Sons of kings': 2,
#  'Category:Special effects people': 2,
#  'Category:Singer-songwriters from California': 2,
#  'Category:April': 2,
#  'Category:Angle': 2,
#  'Category:Writers about the Soviet Union': 2,
#  'Category:Modernist writers': 2,
#  'Category:French male essayists': 2,
#  'Category:French anti-communists': 2,
#  'Category:Writers from Hampstead': 2,
#  'Category:English male poets': 2,
#  "Category:English children's writers": 2,
#  'Category:English autobiographers': 2,
#  'Category:20th-century British dramatists and playwrights': 2,
#  'Category:History of the Mediterranean': 2,
#  'Category:Alkali metals': 2,
#  'Category:Language families': 2,
#  'Category:Anarchism': 2,
#  'Category:Unix text editors': 1,
#  'Category:Computer programming tool stubs': 1,
#  'Category:1981 software': 1,
#  'Category:World War II submarines of Germany': 1,
#  'Category:U-boats commissioned in 1941': 1,
#  'Category:Submarines of the Spanish Navy': 1,
#  'Category:Submarines of Spain': 1,
#  'Category:Spain in World War II': 1,
#  'Category:Ships built in Hamburg': 1,
#  'Category:Maritime incidents in Spain': 1,
#  'Category:Maritime incidents in May 1942': 1,
#  'Category:German Type VIIC submarines': 1,
#  'Category:1941 ships': 1,
#  'Category:NeXT': 1,
#  'Category:Data management': 1,
#  'Category:Apple Inc. software': 1,
#  'Category:Solutions': 1,
#  'Category:Physical properties': 1,
#  'Category:Standard Oil': 1,
#  'Category:Retail companies established in 2017': 1,
#  'Category:Retail companies established in 1889': 1,
#  'Category:Retail companies disestablished in 2004': 1,
#  'Category:Oil pipeline companies': 1,
#  'Category:Non-renewable resource companies established in 2017': 1,
#  'Category:Non-renewable resource companies established in 1889': 1,
#  'Category:Non-renewable resource companies disestablished in 2004': 1,
#  'Category:Natural gas companies of the United States': 1,
#  'Category:Energy companies established in 2017': 1,
#  'Category:Energy companies established in 1889': 1,
#  'Category:Defunct oil companies of the United States': 1,
#  'Category:Companies based in Cook County, Illinois': 1,
#  'Category:Companies based in Chicago': 1,
#  'Category:BP subsidiaries': 1,
#  'Category:Amoco': 1,
#  'Category:2017 establishments in Illinois': 1,
#  'Category:2004 disestablishments in Illinois': 1,
#  'Category:1889 establishments in Indiana': 1,
#  'Category:Thioethers': 1,
#  'Category:Sulfur amino acids': 1,
#  'Category:Proteinogenic amino acids': 1,
#  'Category:Glucogenic amino acids': 1,
#  'Category:Essential amino acids': 1,
#  'Category:Alpha-Amino acids': 1,
#  'Category:488 BC': 1,
#  'Category:32 BC': 1,
#  'Category:Sports leagues established in 1999': 1,
#  'Category:Sports leagues disestablished in 2009': 1,
#  'Category:AF2': 1,
#  'Category:2009 disestablishments in the United States': 1,
#  'Category:Medical lists': 1,
#  'Category:Genetic diseases and disorders': 1,
#  'Category:Disability-related lists': 1,
#  'Category:Health law': 1,
#  'Category:Young adult science fiction novels': 1,
#  'Category:Works originally published in Analog Science Fiction and Fact': 1,
#  'Category:Works based on short fiction': 1,
#  'Category:Works about child soldiers': 1,
#  'Category:Tor Books books': 1,
#  'Category:Novels set in the 22nd century': 1,
#  'Category:Nebula Award for Best Novel-winning works': 1,
#  'Category:Military science fiction novels': 1,
#  'Category:Hugo Award for Best Novel-winning works': 1,
#  'Category:Fictional video games': 1,
#  'Category:Fiction books about genocide': 1,
#  'Category:Fiction about space warfare': 1,
#  "Category:Ender's Game series books": 1,
#  'Category:433 Eros': 1,
#  'Category:1985 science fiction novels': 1,
#  'Category:Regius Professors of Civil Law (University of Oxford)': 1,
#  'Category:Principals of St Alban Hall, Oxford': 1,
#  'Category:People educated at Winchester College': 1,
#  "Category:Members of Doctors' Commons": 1,
#  'Category:English MPs 1621–1622': 1,
#  'Category:Alumni of New College, Oxford': 1,
#  'Category:17th-century English judges': 1,
#  'Category:1661 deaths': 1,
#  'Category:Scottish inventors': 1,
#  'Category:People from Angus, Scotland': 1,
#  'Category:People associated with Dundee': 1,
#  'Category:Alumni of the University of St Andrews': 1,
#  'Category:Technology timelines': 1,
#  'Category:Spaceflight timelines': 1,
#  'Category:Science timelines': 1,
#  'Category:Military timelines': 1,
#  'Category:Aviation timelines': 1,
#  'Category:Neuroendocrinology': 1,
#  'Category:Limbic system': 1,
#  'Category:Hypothalamus': 1,
#  'Category:Human female endocrine system': 1,
#  'Category:Straits': 1,
#  'Category:Coastal and oceanic landforms': 1,
#  'Category:Bodies of water': 1,
#  'Category:Think tanks based in the State of Palestine': 1,
#  'Category:Palestinian nationalism': 1,
#  'Category:Organizations based in Jerusalem': 1,
#  'Category:Non-profit organizations based in the State of Palestine': 1,
#  'Category:Non-governmental organizations involved in the Israeli–Palestinian conflict': 1,
#  'Category:Educational institutions established in 1987': 1,
#  'Category:1987 establishments in the Palestinian territories': 1,
#  'Category:Populated places established in the 9th century': 1,
#  'Category:Municipalities in the Province of Badajoz': 1,
#  'Category:Badajoz': 1,
#  'Category:9th-century establishments in Spain': 1,
#  'Category:875 establishments': 1,
#  'Category:Aircraft wing design': 1,
#  'Category:Italian slasher films': 1,
#  'Category:Italian serial killer films': 1,
#  'Category:Italian mystery thriller films': 1,
#  'Category:Italian horror thriller films': 1,
#  'Category:Italian crime thriller films': 1,
#  'Category:Giallo films': 1,
#  'Category:Films shot in Barcelona': 1,
#  'Category:Films scored by Bruno Nicolai': 1,
#  'Category:Films directed by Umberto Lenzi': 1,
#  'Category:1970s slasher films': 1,
#  'Category:1970s serial killer films': 1,
#  'Category:1970s mystery thriller films': 1,
#  'Category:1970s horror thriller films': 1,
#  'Category:1970s horror film stubs': 1,
#  'Category:1970s exploitation films': 1,
#  'Category:1970s crime thriller films': 1,
#  'Category:1970s Italian film stubs': 1,
#  'Category:Michigan geography-related lists': 1,
#  'Category:Michigan counties': 1,
#  'Category:Lists of counties of the United States by state': 1,
#  'Category:Peerages in the United Kingdom': 1,
#  'Category:World Heritage Sites in Lebanon': 1,
#  'Category:Tourist attractions in Lebanon': 1,
#  'Category:Tourism in Lebanon': 1,
#  'Category:Sunni Muslim communities in Lebanon': 1,
#  'Category:Roman sites in Lebanon': 1,
#  'Category:Pre-Pottery Neolithic B': 1,
#  'Category:Populated places in Baalbek District': 1,
#  'Category:Populated places established in the 7th millennium BC': 1,
#  'Category:Phoenician sites in Lebanon': 1,
#  'Category:Phoenician cities': 1,
#  'Category:Great Rift Valley': 1,
#  'Category:Coloniae (Roman)': 1,
#  'Category:Archaeological sites in Lebanon': 1,
#  'Category:7th-millennium BC establishments': 1,
#  'Category:77 BC': 1,
#  'Category:Television networks in the United Kingdom': 1,
#  'Category:ITV (TV network)': 1,
#  'Category:State holidays in the United States': 1,
#  'Category:Public holidays in the United Kingdom': 1,
#  'Category:Public holidays in the Republic of Ireland': 1,
#  'Category:Public holidays in the Philippines': 1,
#  'Category:Public holidays in the Dominican Republic': 1,
#  'Category:Public holidays in the Czech Republic': 1,
#  'Category:Public holidays in the Bahamas': 1,
#  'Category:Public holidays in Zimbabwe': 1,
#  'Category:Public holidays in Zambia': 1,
#  'Category:Public holidays in Venezuela': 1,
#  'Category:Public holidays in Uganda': 1,
#  'Category:Public holidays in Trinidad and Tobago': 1,
#  'Category:Public holidays in Tanzania': 1,
#  'Category:Public holidays in Switzerland': 1,
#  'Category:Public holidays in Sweden': 1,
#  'Category:Public holidays in Sri Lanka': 1,
#  'Category:Public holidays in Spain': 1,
#  'Category:Public holidays in South Africa': 1,
#  'Category:Public holidays in Slovakia': 1,
#  'Category:Public holidays in Singapore': 1,
#  'Category:Public holidays in Rwanda': 1,
#  'Category:Public holidays in Portugal': 1,
#  'Category:Public holidays in Peru': 1,
#  'Category:Public holidays in Paraguay': 1,
#  'Category:Public holidays in Norway': 1,
#  'Category:Public holidays in Nigeria': 1,
#  'Category:Public holidays in New Zealand': 1,
#  'Category:Public holidays in Mexico': 1,
#  'Category:Public holidays in Malta': 1,
#  'Category:Public holidays in Malaysia': 1,
#  'Category:Public holidays in Luxembourg': 1,
#  'Category:Public holidays in Liechtenstein': 1,
#  'Category:Public holidays in Latvia': 1,
#  'Category:Public holidays in Kenya': 1,
#  'Category:Public holidays in Jamaica': 1,
#  'Category:Public holidays in Indonesia': 1,
#  'Category:Public holidays in India': 1,
#  'Category:Public holidays in Iceland': 1,
#  'Category:Public holidays in Hungary': 1,
#  'Category:Public holidays in Honduras': 1,
#  'Category:Public holidays in Grenada': 1,
#  'Category:Public holidays in Greece': 1,
#  'Category:Public holidays in Ghana': 1,
#  'Category:Public holidays in Germany': 1,
#  'Category:Public holidays in France': 1,
#  'Category:Public holidays in Finland': 1,
#  'Category:Public holidays in Fiji': 1,
#  'Category:Public holidays in Estonia': 1,
#  'Category:Public holidays in El Salvador': 1,
#  'Category:Public holidays in Denmark': 1,
#  'Category:Public holidays in Costa Rica': 1,
#  'Category:Public holidays in Colombia': 1,
#  'Category:Public holidays in Chile': 1,
#  'Category:Public holidays in Canada': 1,
#  'Category:Public holidays in Brazil': 1,
#  'Category:Public holidays in Botswana': 1,
#  'Category:Public holidays in Bolivia': 1,
#  'Category:Public holidays in Barbados': 1,
#  'Category:Public holidays in Australia': 1,
#  'Category:Public holidays in Argentina': 1,
#  'Category:Public holidays in Angola': 1,
#  'Category:March observances': 1,
#  'Category:Holy Week': 1,
#  'Category:Greek traditions': 1,
#  'Category:Friday observances': 1,
#  'Category:Divine Mercy (Catholic devotion)': 1,
#  'Category:Crucifixion of Jesus': 1,
#  'Category:April observances': 1,
#  'Category:Tennessee counties': 1,
#  'Category:Populated places established in 1796': 1,
#  'Category:Montgomery County, Tennessee': 1,
#  'Category:Middle Tennessee': 1,
#  'Category:Clarksville metropolitan area': 1,
#  'Category:1796 establishments in Tennessee': 1,
#  "Category:Second Barons' War": 1,
#  'Category:Registered historic battlefields in England': 1,
#  'Category:Military history of Worcestershire': 1,
#  'Category:Evesham': 1,
#  'Category:Edward I of England': 1,
#  'Category:Conflicts in 1265': 1,
#  "Category:Battles of the Barons' Wars": 1,
#  'Category:1265 in England': 1,
#  'Category:Percussionists': 1,
#  'Category:Lists of musicians by instrument': 1,
#  'Category:Populated places established in 1807': 1,
#  'Category:Kentucky counties': 1,
#  'Category:Counties of Appalachia': 1,
#  'Category:Clay County, Kentucky': 1,
#  'Category:1807 establishments in Kentucky': 1,
#  'Category:Wildfires in Colorado': 1,
#  'Category:Natural disasters in Colorado': 1,
#  'Category:Mass murder in 2002': 1,
#  'Category:Arson in Colorado': 1,
#  'Category:2002 wildfires in the United States': 1,
#  'Category:2002 in Colorado': 1,
#  'Category:Ramjet engines': 1,
#  'Category:Projects of the United States Air Force': 1,
#  'Category:Nuclear research reactors': 1,
#  'Category:Nuclear propulsion': 1,
#  'Category:Nevada Test Site': 1,
#  'Category:Military nuclear reactors': 1,
#  'Category:Engineering projects': 1,
#  'Category:Abandoned military projects of the United States': 1,
#  'Category:Foreign relations of Norway': 1,
#  'Category:Tropical agriculture': 1,
#  'Category:Palm oil': 1,
#  'Category:Environmental controversies': 1,
#  'Category:Crops': 1,
#  'Category:Warner Bros. Games': 1,
#  'Category:Video game companies of the United States': 1,
#  'Category:Video game companies established in 1994': 1,
#  'Category:Needham, Massachusetts': 1,
#  'Category:Companies based in Norfolk County, Massachusetts': 1,
#  'Category:2010 mergers and acquisitions': 1,
#  'Category:1994 establishments in Massachusetts': 1,
#  'Category:Port cities in the Caribbean': 1,
#  'Category:Port-au-Prince': 1,
#  'Category:Populated places in Ouest (department)': 1,
#  'Category:Populated places established in 1749': 1,
#  'Category:Populated coastal places in Haiti': 1,
#  'Category:Gulf of Gonâve': 1,
#  'Category:Communes of Haiti': 1,
#  'Category:Capitals in the Caribbean': 1,
#  'Category:Capitals in North America': 1,
#  'Category:1749 establishments in the French colonial empire': 1,
#  'Category:Populated places established in 1853': 1,
#  'Category:Iowa counties': 1,
#  'Category:Adams County, Iowa': 1,
#  'Category:1853 establishments in Iowa': 1,
#  'Category:TGV': 1,
#  'Category:SNCF brands': 1,
#  'Category:SNCF': 1,
#  'Category:Railway services introduced in 1981': 1,
#  'Category:Railteam': 1,
#  'Category:Rail transport in Europe': 1,
#  'Category:Rail transport brands': 1,
#  'Category:Land speed records': 1,
#  'Category:High-speed trains': 1,
#  'Category:High-speed rail in France': 1,
#  'Category:Eurostar': 1,
#  'Category:1981 establishments in France': 1,
#  'Category:Provinces of the Netherlands': 1,
#  'Category:Overijssel': 1,
#  'Category:History of the Marshall Islands': 1,
#  'Category:Birds of prey': 1,
#  'Category:Bird common names': 1,
#  'Category:Writers from Saskatchewan': 1,
#  'Category:University of Toronto alumni': 1,
#  'Category:University of Toronto Faculty of Law alumni': 1,
#  'Category:University of Manitoba alumni': 1,
#  'Category:People from Weyburn': 1,
#  'Category:Members of the Order of Canada': 1,
#  'Category:Lawyers in Ontario': 1,
#  'Category:Canadian male novelists': 1,
#  'Category:Canadian fantasy writers': 1,
#  'Category:Aurora Award-winning writers': 1,
#  'Category:21st-century Canadian novelists': 1,
#  'Category:20th-century Canadian novelists': 1,
#  'Category:South-East District (Botswana)': 1,
#  'Category:Populated places established in 1964': 1,
#  'Category:Planned capitals': 1,
#  'Category:New towns started in the 1960s': 1,
#  'Category:Gaborone': 1,
#  'Category:District capitals in Botswana': 1,
#  'Category:Cities in Botswana': 1,
#  'Category:Capitals in Africa': 1,
#  'Category:1964 establishments in Africa': 1,
#  'Category:NGC objects': 1,
#  'Category:IC objects': 1,
#  'Category:Astronomical catalogues': 1,
#  'Category:1888 in science': 1,
#  'Category:1888 documents': 1,
#  'Category:Political spectrum': 1,
#  'Category:Writers on Zionism': 1,
#  'Category:Right-wing populists': 1,
#  'Category:Right-wing populism in Israel': 1,
#  'Category:Politicians from Tel Aviv': 1,
#  'Category:Politicians from Jerusalem': 1,
#  'Category:Permanent Representatives of Israel to the United Nations': 1,
#  'Category:People of the Military Intelligence Directorate (Israel)': 1,
#  'Category:People from Cheltenham, Pennsylvania': 1,
#  'Category:Netanyahu family': 1,
#  'Category:Ministers of finance of Israel': 1,
#  'Category:Ministers of Justice of Israel': 1,
#  'Category:Ministers of Communications of Israel': 1,
#  'Category:Members of the 25th Knesset (2022–)': 1,
#  'Category:Members of the 24th Knesset (2021–2022)': 1,
#  'Category:Members of the 23rd Knesset (2020–2021)': 1,
#  'Category:Members of the 22nd Knesset (2019–2020)': 1,
#  'Category:Members of the 21st Knesset (2019)': 1,
#  'Category:Members of the 20th Knesset (2015–2019)': 1,
#  'Category:Members of the 19th Knesset (2013–2015)': 1,
#  'Category:Members of the 18th Knesset (2009–2013)': 1,
#  'Category:Members of the 17th Knesset (2006–2009)': 1,
#  'Category:MIT Sloan School of Management alumni': 1,
#  'Category:MIT School of Architecture and Planning alumni': 1,
#  'Category:Leaders of the Opposition (Israel)': 1,
#  'Category:Jewish non-fiction writers': 1,
#  'Category:Jewish Israeli writers': 1,
#  'Category:Jewish Israeli politicians': 1,
#  'Category:Israeli soldiers': 1,
#  'Category:Israeli secular Jews': 1,
#  'Category:Israeli political writers': 1,
#  'Category:Israeli people of Polish-Jewish descent': 1,
#  'Category:Israeli people of Lithuanian-Jewish descent': 1,
#  'Category:Israeli nationalists': 1,
#  'Category:Israeli management consultants': 1,
#  'Category:Israeli male non-fiction writers': 1,
#  'Category:Israeli expatriates in the United States': 1,
#  'Category:Israeli chief executives': 1,
#  'Category:Deputy ministers of Israel': 1,
#  'Category:Chief marketing officers': 1,
#  'Category:Boston Consulting Group people': 1,
#  'Category:Benjamin Netanyahu': 1,
#  'Category:21st-century diplomats': 1,
#  'Category:20th-century prime ministers of Israel': 1,
#  'Category:20th-century non-fiction writers': 1,
#  'Category:20th-century diplomats': 1,
#  'Category:20th-century Israeli male writers': 1,
#  'Category:Opera composers': 1,
#  'Category:Opera-related lists': 1,
#  'Category:Lists of composers': 1,
#  'Category:Jack Dann and Gardner Dozois Ace anthologies': 1,
#  'Category:Fiction about nanotechnology': 1,
#  'Category:Ace Books books': 1,
#  'Category:1998 anthologies': 1,
#  'Category:Suspected fetotoxicants': 1,
#  'Category:Reproductive toxicants': 1,
#  'Category:Monomers': 1,
#  'Category:IARC Group 2A carcinogens': 1,
#  'Category:Carboxamides': 1,
#  'Category:Acrylamides': 1,
#  'Category:Rochester metropolitan area, New York': 1,
#  'Category:Populated places established in 1824': 1,
#  'Category:Orleans County, New York': 1,
#  'Category:1824 establishments in New York (state)': 1,
#  'Category:Takeover defense': 1,
#  'Category:Shareholders': 1,
#  'Category:Metaphors referring to war and violence': 1,
#  'Category:Mergers and acquisitions': 1,
#  'Category:Tongue': 1,
#  'Category:Speech organs': 1,
#  'Category:Sensory organs': 1,
#  'Category:Human mouth anatomy': 1,
#  'Category:Gustatory system': 1,
#  'Category:Digestive system': 1,
#  "Category:Men's health": 1,
#  'Category:Inflammatory prostate disorders': 1,
#  'Category:Inflammations': 1,
#  'Category:Logic': 1,
#  'Category:History of logic': 1,
#  'Category:Classical logic': 1,
#  'Category:United States federal securities legislation': 1,
#  'Category:United States federal legislation stubs': 1,
#  'Category:1934 in international relations': 1,
#  'Category:1934 in economic history': 1,
#  'Category:United States railroad regulation': 1,
#  'Category:United States federal transportation legislation': 1,
#  'Category:Progressive Era in the United States': 1,
#  'Category:1910 in rail transport': 1,
#  'Category:Hospitals': 1,
#  'Category:Hospital staff': 1,
#  'Category:Regions of Europe': 1,
#  'Category:Geography of the European Union': 1,
#  'Category:United States federal trade legislation': 1,
#  'Category:Andrew Jackson': 1,
#  'Category:22nd United States Congress': 1,
#  'Category:1833 in the United States': 1,
#  'Category:10th century BC': 1,
#  'Category:Simon & Schuster books': 1,
#  'Category:Satirical novels': 1,
#  'Category:Novels set during World War II': 1,
#  'Category:Novels by Joseph Heller': 1,
#  'Category:Nonlinear narrative novels': 1,
#  'Category:Military humor': 1,
#  'Category:Fiction set in 1943': 1,
#  'Category:Fiction about the United States Army': 1,
#  'Category:Fiction about suicide': 1,
#  'Category:Censored books': 1,
#  'Category:Catch-22': 1,
#  'Category:Bureaucracy in fiction': 1,
#  'Category:Books with cover art by Paul Bacon': 1,
#  'Category:Books about Assyrian people': 1,
#  'Category:Black comedy books': 1,
#  'Category:Aviation novels': 1,
#  'Category:Anti-war novels': 1,
#  'Category:1961 debut novels': 1,
#  'Category:Hard disk drives': 1,
#  'Category:Star Trek spacecraft': 1,
#  'Category:Star Trek: Voyager': 1,
#  'Category:Bioships': 1,
#  'Category:Utah politicians': 1,
#  'Category:Singer-songwriters from Utah': 1,
#  'Category:Singer-songwriters from Ohio': 1,
#  'Category:Red House Records artists': 1,
#  'Category:Politicians from Cleveland': 1,
#  'Category:Political music artists': 1,
#  'Category:People from Nevada City, California': 1,
#  'Category:Peace and Freedom Party politicians': 1,
#  'Category:Musicians from Salt Lake City': 1,
#  'Category:Musicians from Cleveland': 1,
#  'Category:Industrial Workers of the World members': 1,
#  'Category:Industrial Workers of the World culture': 1,
#  'Category:Christian anarchists': 1,
#  'Category:Catholic Workers': 1,
#  'Category:Anarcho-pacifists': 1,
#  'Category:Activists from California': 1,
#  'Category:2008 deaths': 1,
#  'Category:World Heritage Sites in Danger': 1,
#  'Category:World Heritage Sites in Croatia': 1,
#  'Category:Ports and harbours of Croatia': 1,
#  'Category:Populated places in Dubrovnik-Neretva County': 1,
#  'Category:Populated places established in the 7th century': 1,
#  'Category:Populated coastal places in Croatia': 1,
#  'Category:Mediterranean port cities and towns in Croatia': 1,
#  'Category:Kingdom of Dalmatia': 1,
#  'Category:Illyrian Croatia': 1,
#  'Category:Dubrovnik': 1,
#  'Category:Dalmatia': 1,
#  'Category:Cities and towns in Croatia': 1,
#  'Category:7th-century establishments in Europe': 1,
#  'Category:Seafood': 1,
#  'Category:Fish products': 1,
#  'Category:Edible shellfish': 1,
#  'Category:Upstate New York': 1,
#  'Category:Regions of New York (state)': 1,
#  'Category:Mountain ranges of New York (state)': 1,
#  'Category:Zingiber': 1,
#  'Category:Spices': 1,
#  'Category:Rhizomatous plants': 1,
#  'Category:Indian spices': 1,
#  'Category:Ginger': 1,
#  'Category:Robbery': 1,
#  'Category:Illegal occupations': 1,
#  'Category:Crimes': 1,
#  'Category:Television personalities from London': 1,
#  'Category:Special Tony Award recipients': 1,
#  'Category:Sony Classical Records artists': 1,
#  'Category:Recipients of the Praemium Imperiale': 1,
#  'Category:People from Belgravia': 1,
#  'Category:Peers retired under the House of Lords Reform Act 2014': 1,
#  'Category:Oratorio composers': 1,
#  'Category:Musicians who were peers': 1,
#  'Category:Musicians from Kensington': 1,
#  'Category:Musicians awarded knighthoods': 1,
#  'Category:Lloyd Webber family': 1,
#  'Category:Life peers created by Elizabeth II': 1,
#  'Category:Grammy Legend Award winners': 1,
#  'Category:Golden Globe Award-winning musicians': 1,
#  'Category:English theatre managers and producers': 1,
#  'Category:English theatre directors': 1,
#  'Category:English television personalities': 1,
#  'Category:English record producers': 1,
#  'Category:English racehorse owners and breeders': 1,
#  'Category:English philanthropists': 1,
#  'Category:English opera composers': 1,
#  'Category:English musical theatre composers': 1,
#  'Category:English male songwriters': 1,
#  'Category:English male film score composers': 1,
#  'Category:English male composers': 1,
#  'Category:English film score composers': 1,
#  'Category:English billionaires': 1,
#  'Category:English art collectors': 1,
#  'Category:Conservative Party (UK) people': 1,
#  'Category:Conservative Party (UK) life peers': 1,
#  'Category:Composers from London': 1,
#  'Category:Composers awarded knighthoods': 1,
#  'Category:Broadway theatre producers': 1,
#  'Category:British ballet composers': 1,
#  'Category:Best Original Song Academy Award-winning songwriters': 1,
#  'Category:Andrew Lloyd Webber': 1,
#  'Category:Alumni of the Royal College of Music': 1,
#  'Category:21st-century English memoirists': 1,
#  'Category:21st-century English composers': 1,
#  'Category:20th-century English composers': 1,
#  'Category:Complexity classes': 1,
#  'Category:Tricarboxylic acids': 1,
#  'Category:Photographic chemicals': 1,
#  'Category:Household chemicals': 1,
#  'Category:Food acidity regulators': 1,
#  'Category:Condiments': 1,
#  'Category:Citrates': 1,
#  'Category:Chelating agents': 1,
#  'Category:Alpha hydroxy acids': 1,
#  'Category:Types of musical groups': 1,
#  'Category:Jazz ensembles': 1,
#  'Category:Populated places established in 1847': 1,
#  'Category:Hamilton County, New York': 1,
#  'Category:Adirondack Park': 1,
#  'Category:1847 establishments in New York (state)': 1,
#  'Category:World motorcycle racing series': 1,
#  'Category:Motorcycle road racing series': 1,
#  'Category:Grand Prix motorcycle racing': 1,
#  'Category:Fédération Internationale de Motocyclisme': 1,
#  'Category:1949 establishments in Europe': 1,
#  'Category:Supernatural action films': 1,
#  'Category:Lucasfilm films': 1,
#  'Category:Indiana Jones films': 1,
#  'Category:IMAX films': 1,
#  'Category:Hugo Award for Best Dramatic Presentation winning works': 1,
#  'Category:Films with screenplays by Philip Kaufman': 1,
#  'Category:Films with screenplays by Lawrence Kasdan': 1,
#  'Category:Films with screenplays by George Lucas': 1,
#  'Category:Films that won the Best Visual Effects Academy Award': 1,
#  'Category:Films that won the Best Sound Mixing Academy Award': 1,
#  'Category:Films that won the Best Sound Editing Academy Award': 1,
#  'Category:Films shot in the United Kingdom': 1,
#  'Category:Films shot in Tunisia': 1,
#  'Category:Films shot in San Francisco': 1,
#  'Category:Films shot in Hawaii': 1,
#  'Category:Films shot in France': 1,
#  'Category:Films shot in England': 1,
#  'Category:Films shot in Africa': 1,
#  'Category:Films shot at EMI-Elstree Studios': 1,
#  'Category:Films set in the 1930s': 1,
#  'Category:Films set in Southeast Asia': 1,
#  'Category:Films set in South America': 1,
#  'Category:Films set in Peru': 1,
#  'Category:Films set in North Africa': 1,
#  'Category:Films set in Nepal': 1,
#  'Category:Films set in Europe': 1,
#  'Category:Films set in Asia': 1,
#  'Category:Films set in 1936': 1,
#  'Category:Films produced by Frank Marshall': 1,
#  'Category:Films directed by Steven Spielberg': 1,
#  'Category:Films about poisonings': 1,
#  'Category:Films about Nazis': 1,
#  'Category:Ark of the Covenant': 1,
#  'Category:1981 films': 1,
#  'Category:1980s supernatural films': 1,
#  'Category:1980s action adventure films': 1,
#  'Category:1980s English-language films': 1,
#  'Category:Tram transport-related lists': 1,
#  'Category:Light rail': 1,
#  'Category:Types of horse': 1,
#  'Category:Lists of breeds': 1,
#  'Category:Horse breeds': 1,
#  'Category:Legends': 1,
#  'Category:Folklore': 1,
#  'Category:Category theory': 1,
#  'Category:Algebraic structures': 1,
#  'Category:Treaty on European Union': 1,
#  'Category:Urban theorists': 1,
#  'Category:Urban designers': 1,
#  'Category:Structuralists': 1,
#  'Category:Safdie family': 1,
#  'Category:Recipients of the AIA Gold Medal': 1,
#  'Category:People from Haifa': 1,
#  'Category:Modernist architecture in Canada': 1,
#  'Category:Modernist architects': 1,
#  ...}

# %%
def remove_maintenance_categories(categories):
    URL = "https://en.wikipedia.org/wiki/"
    cat_to_delete = []
    for k, v in categories.items():
        body = session.get(URL+k)
        if "maintenance" in body.text:
            cat_to_delete.append(k)
            print(k)
    for k in cat_to_delete:
        del categories[k]
    return categories, cat_to_delete

# %%
len(sorted_hashmap)
# Out:
# 6862
